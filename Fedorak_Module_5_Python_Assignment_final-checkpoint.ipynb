# %% [markdown]
# # MSDS 430 Module 5 Python Assignment

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>In this assignment you will read through the notebook and complete the exercises. Once you are satisfied with the results, submit your notebook and html file to Canvas. Your files should include all output, i.e. run each cell and save your file before submitting.</b></div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Research project problem statement:
#
# There are world happiness surveys conducted every year for many countries around the world. Happiness is measured on such subjective topics as social support, freedom, generosity, corruption, government trust, positive and negative affects.
# <br>
#
# This study will look at the happiness measures over multiple years to determine which of the measures are related to the overall happiness of a country.  And we will look at population of a country to see if this has any relationship to the happiness measures. Are larger countries based on population happier than smaller countries?
# <br>
#
# ### Objectives for cleaning and prepping the data:
#
# - Read the happiness data and population data into dataframes.
# - Use the methods `info, head, tail, shape` to inspect the data in the dataframes
# - Use the method `describe` to obtain some statistics for the numerical data
# - Create boxplots to check for outliers
# - Drop null values, drop/select columns, select rows, and rename column names
# - Use the method `value_counts` to obtain counts of unique rows in a dataframe
# - Create sub-dataframes by selecting subset of rows and columns
# - Convert dataframes from wide to long formats
# - Merge the happiness and population dataframes
# </div>

# %% [markdown]
# ### References:
#
# __[World Happiness Report Apendices and Data](https://worldhappiness.report/ed/2022/#appendices-and-data)__
#
# How the indices are calculated for each country: __[World Happiness Report FAQ](https://worldhappiness.report/faq/)__
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Part I - Happiness measures
#
# <i>Below is an example of a table created using HTML. This table explains what each of the happiness variables represents.  Check out the code in this Markdown cell to see how to create the table.  This format is perfect for a data dictionary which you will be doing in your EDA 2 homework.</i><br>
#
# | Measure Name | Description | Source |
# | --- | --- | --- |
# | GDP per capita | Log of purchasing power parity adjusted to constant 2017 international dollars | World Bank |
# | Healthy life expectancy | Life expectancy from birth | World Health Organization |
# | Social Support | Subjective response to 'if you were in trouble, do you have relatives or friends to count on...' | Gallup World Poll |
# | Freedom | Subjective response to 'Are you satisfied or dissatisfied with your freedom to choose what to do with your life' | Gallop World Poll |
# | Generosity | Subjective response to Donating money to charity as relates to GDP per capita | Gallop World Poll |
# | Perception of corruption | Subjective response about corruption as it relates to government and to businesses | Gallop World Poll |
# | Positive affect | Subjective response to previous day experience of laughter, enjoyment or learn/do something interesting yesterday. | Gallop World Poll |
# | Negative affect | Subjective response to previous day experience of worry, sadness, anger. | Gallop World Poll |
# | Life ladder | Subjective rating of current life based on the mental image of a ladder with 10 being the highest and 0 for the low | Gallop World Poll |

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Reminder: In all of the problems you will see <font color=black>#TODO</font> statements added as comments on the code cell provided. You will want to be sure to complete each of these as indicated to avoid losing points.</b></div>

# %%
# Set up notebook to display multiple outputs in one cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import numpy as np

# needed for M6
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### .info() provides a lot of information about a dataframe
# - Display the column names, their data types, as well as the non-null value count for each column.
# - Also indicate the row index range in `RangeIndex`.
# - From the row index range, we know the total number of rows the dataframe contains and the number of null values in each column of the dataframe.

# %%
# read in happiness scores
df = pd.read_excel('world_happiness_scores.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2089 entries, 0 to 2088
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country name                       2089 non-null   object
#  1   year                               2089 non-null   int64
#  2   Life Ladder                        2089 non-null   float64
#  3   Log GDP per capita                 2062 non-null   float64
#  4   Social support                     2076 non-null   float64
#  5   Healthy life expectancy at birth   2031 non-null   float64
#  6   Freedom to make life choices       2057 non-null   float64
#  7   Generosity                         2009 non-null   float64
#  8   Perceptions of corruption          1976 non-null   float64
#  9   Positive affect                    2065 non-null   float64
#  10  Negative affect                    2073 non-null   float64
#  11  Confidence in national government  1873 non-null   float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 196.0+ KB

# %% [markdown]
# ### Additional info on data
#
# - Use the DataFrame `head()` and `tail()` methods to become familiar with the data values. For example, the higher the values of **Social Support**, the **better** for the country, while the higher the value of **Perceptions of corruption** the **worse** the condition.

# %%
df.head()
df.tail()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.302574        0.450662
# 1  Afghanistan  2009     4.401778            7.472446        0.552308
# 2  Afghanistan  2010     4.758381            7.579183        0.539075
# 3  Afghanistan  2011     3.831719            7.552006        0.521104
# 4  Afghanistan  2012     3.782938            7.637953        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.500000                      0.718114    0.173169
# 1                         50.799999                      0.678896    0.195469
# 2                         51.099998                      0.600127    0.125859
# 3                         51.400002                      0.495901    0.167723
# 4                         51.700001                      0.530935    0.241247
#
#    Perceptions of corruption  Positive affect  Negative affect  \
# 0                   0.881686         0.414297         0.258195
# 1                   0.850035         0.481421         0.237092
# 2                   0.706766         0.516907         0.275324
# 3                   0.731109         0.479835         0.267175
# 4                   0.775620         0.613513         0.267919
#
#    Confidence in national government
# 0                           0.612072
# 1                           0.611545
# 2                           0.299357
# 3                           0.307386
# 4                           0.435440
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 2084     Zimbabwe  2017     3.638300            8.241609        0.754147
# 2085     Zimbabwe  2018     3.616480            8.274620        0.775388
# 2086     Zimbabwe  2019     2.693523            8.196998        0.759162
# 2087     Zimbabwe  2020     3.159802            8.117733        0.717243
# 2088     Zimbabwe  2021     3.154578            8.153248        0.685151
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 2084                         52.150002                      0.752826
# 2085                         52.625000                      0.762675
# 2086                         53.099998                      0.631908
# 2087                         53.575001                      0.643303
# 2088                         54.049999                      0.667636
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 2084   -0.113937                   0.751208         0.733641         0.224051
# 2085   -0.084747                   0.844209         0.657524         0.211726
# 2086   -0.081540                   0.830652         0.658434         0.235354
# 2087   -0.029376                   0.788523         0.660658         0.345736
# 2088   -0.109439                   0.756945         0.609917         0.241682
#
#       Confidence in national government
# 2084                           0.682647
# 2085                           0.550508
# 2086                           0.456455
# 2087                           0.577302
# 2088                           0.665703

# %% [markdown]
# ### Descriptive statistics
#
# `describe()` shows each numerical column along with the count, mean and standard deviation for each.

# %%
# look at the statitics of each numerical variable
df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2089.000000  2089.000000         2062.000000     2076.000000
# mean   2013.727621     5.473747            9.378408        0.811542
# std       4.455614     1.115567            1.143520        0.118935
# min    2005.000000     2.178809            5.526723        0.290184
# 25%    2010.000000     4.651972            8.473547        0.747664
# 50%    2014.000000     5.405246            9.463269        0.834770
# 75%    2017.000000     6.294282           10.347656        0.904682
# max    2021.000000     8.018934           11.665803        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2031.000000                   2057.000000
# mean                          63.180326                      0.745462
# std                            6.948546                      0.140751
# min                            6.720000                      0.257534
# 25%                           58.965000                      0.651689
# 50%                           64.980003                      0.767357
# 75%                           68.362499                      0.857677
# max                           74.349998                      0.985178
#
#         Generosity  Perceptions of corruption  Positive affect  \
# count  2009.000000                1976.000000      2065.000000
# mean      0.000102                   0.746474         0.651421
# std       0.161082                   0.186136         0.105954
# min      -0.335739                   0.035198         0.178886
# 25%      -0.113172                   0.689840         0.570057
# 50%      -0.023366                   0.801339         0.662837
# 75%       0.090584                   0.870789         0.737176
# max       0.706377                   0.983276         0.883586
#
#        Negative affect  Confidence in national government
# count      2073.000000                        1873.000000
# mean          0.270544                           0.483914
# std           0.085849                           0.191515
# min           0.082737                           0.068769
# 25%           0.207652                           0.334808
# 50%           0.260328                           0.467046
# 75%           0.321706                           0.616302
# max           0.704590                           0.993604

# %% [markdown]
# ### Renaming column names
#
# - We can use the `rename()` method to rename one or more of a dataframe's columns
# - Create a dictionary with old and new column names represented as `key` and `value` pairs:<br>
#   `{'old column name 1':'new column name 1', 'old column name 2':'new column name 2',...}`.
# - Assign this dictionary to the `columns` parameter of the `rename()` method
# - Note that you must use the *exact* names for the columns you renaming which includes spaces, casing and any symbols

# %%
# create useable column names
df = df.rename(columns = {'Country name':'Country',
                          'year':'Year'}) 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2089 entries, 0 to 2088
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            2089 non-null   object
#  1   Year                               2089 non-null   int64
#  2   Life Ladder                        2089 non-null   float64
#  3   Log GDP per capita                 2062 non-null   float64
#  4   Social support                     2076 non-null   float64
#  5   Healthy life expectancy at birth   2031 non-null   float64
#  6   Freedom to make life choices       2057 non-null   float64
#  7   Generosity                         2009 non-null   float64
#  8   Perceptions of corruption          1976 non-null   float64
#  9   Positive affect                    2065 non-null   float64
#  10  Negative affect                    2073 non-null   float64
#  11  Confidence in national government  1873 non-null   float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 196.0+ KB

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 1 (2 pts.)</b>:
#
# Rename the columns as described below and do an info statement after to show the changes:
# - Log GDP per capita becomes: Log GDP
# - Healthy life expectancy at birth becomes: Life Expectancy
# - Freedom to make life choices becomes: Choice Freedom
# - Perceptions of corruption becomes: Corruption
# - Confidence in national government becomes: Government confidence
#
# </div>

# %%
#TODO: Rename columns as indicated in the instructions
df = df.rename(columns = {'Log GDP per capita':'Log GDP','Healthy life expectancy at birth':'Life Expectancy',
                         'Freedom to make life choices':'Choice Freedom','Perceptions of corruption':'Corruption',
                         'Confidence in national government':'Government confidence'}) 

#TODO: Display the dataframe info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2089 entries, 0 to 2088
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                2089 non-null   object
#  1   Year                   2089 non-null   int64
#  2   Life Ladder            2089 non-null   float64
#  3   Log GDP                2062 non-null   float64
#  4   Social support         2076 non-null   float64
#  5   Life Expectancy        2031 non-null   float64
#  6   Choice Freedom         2057 non-null   float64
#  7   Generosity             2009 non-null   float64
#  8   Corruption             1976 non-null   float64
#  9   Positive affect        2065 non-null   float64
#  10  Negative affect        2073 non-null   float64
#  11  Government confidence  1873 non-null   float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 196.0+ KB

# %% [markdown]
# ### Evaluating field types
#
# Take a look at each column type to determine if the type should stay as is or be changed.  `Year` is an int64 and `ints` and `floats` are normally used for mathematical calculations.  Since we only need to use Year as a label, let's change it to a string object.
#
# Pandas function `astype()` will change a pandas column data type. For for info see: __[Pandas astype](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html)__

# %%
df['Year'] = df['Year'].astype('str')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2089 entries, 0 to 2088
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                2089 non-null   object
#  1   Year                   2089 non-null   object
#  2   Life Ladder            2089 non-null   float64
#  3   Log GDP                2062 non-null   float64
#  4   Social support         2076 non-null   float64
#  5   Life Expectancy        2031 non-null   float64
#  6   Choice Freedom         2057 non-null   float64
#  7   Generosity             2009 non-null   float64
#  8   Corruption             1976 non-null   float64
#  9   Positive affect        2065 non-null   float64
#  10  Negative affect        2073 non-null   float64
#  11  Government confidence  1873 non-null   float64
# dtypes: float64(10), object(2)
# memory usage: 196.0+ KB

# %% [markdown]
# ### Looking for outliers by using a boxplot

# %%
df.boxplot(column = 'Life Ladder')
# will rotate x axis label
#df.boxplot(column = 'Life Ladder', rot = 55)
# Out:
# <Axes: >

# %% [markdown]
# ### Side by side boxplots
#
# Often it is good to do side by side boxplots of the columns so you can see how columns are similar or different.
# <br>
#
# Scroll back up to the cell where `.describe()` was run to look at the spread of the values of the numeric columns. Look at how some of the variables, like `Life Expectancy`, is so much larger than the other variables.  Putting such disimilar data side by side will make one of the boxplots too small and too hard to read.
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 2 (4 pts.)</b>:
# You need to inspect each numeric field for outliers.  Run a set of boxplots for:
#
# - Side by side boxplots for all seven happiness measures that have a max under 1.
# - Individual boxplots for Life Expectancy and Log GDP
# </div>

# %%
#TODO show side by side boxplots of seven measures
df.boxplot(column =  ['Social support', 'Choice Freedom', 'Generosity', 'Corruption', 'Positive affect', 'Negative affect', 
        'Government confidence'], rot = 55)
# Out:
# <Axes: >

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 2 continued:</b> Create a boxplot for <i>Life Expectancy</i>.</div>

# %%
#TODO: Create a boxplot for Life Expectancy
df.boxplot(column = 'Life Expectancy')
# Out:
# <Axes: >

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 2 continued:</b> Create a boxplot for <i>Log GDP</i>.</div>

# %%
#TODO: Create a boxplot for Log GDP
df.boxplot(column = 'Log GDP')
# Out:
# <Axes: >

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 3 (2 pts.)</b>:
#
# Use a markdown cell to explain what each of the boxplots in Problem 2 shows.
# </div>

# %% [markdown]
# The first plot shown within my problem 2 answer shows side by side plots for comparison between the values of Social support, Choice Freedom, Generosity, Corruption, Positive affect, Negative affect, and Government confidence. Each separate boxplot shows the mean at the green line. This is enclosed in a box which represents the mean plus or minus the standard deviation. The second boxplot shows this information just for the Life Expectancy variable. All of the circles towards the bottom of the boxplot show outliers in the data. Finally, the third boxplot shows data concerning the Log GDP variable, which is shown to be fairly uniform having only one outlier.

# %% [markdown]
# ### Inspection of the `Year` field
#
# We can see below that the earlier years along with 2020 and 2021 have fewer countries represented.  It looks like 2011 through 2019 have a fairly consistent number of countries, but before we decide which years to use, we will investigate the `Year` column.

# %%
# using sort_index puts the order focus on the field and not the count
df['Year'].value_counts().sort_index()
# Out:
# 2005     27
# 2006     89
# 2007    102
# 2008    110
# 2009    114
# 2010    124
# 2011    146
# 2012    142
# 2013    137
# 2014    145
# 2015    143
# 2016    142
# 2017    147
# 2018    142
# 2019    144
# 2020    116
# 2021    119
# Name: Year, dtype: int64

# %% [markdown]
# ### Investigate one year of data
#
# Below we are creating a new dataframe object with only 2011 data.

# %%
yr2011 = df[df['Year'] == '2011']
yr2011.info()
yr2011.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 3 to 2078
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                146 non-null    object
#  1   Year                   146 non-null    object
#  2   Life Ladder            146 non-null    float64
#  3   Log GDP                145 non-null    float64
#  4   Social support         145 non-null    float64
#  5   Life Expectancy        141 non-null    float64
#  6   Choice Freedom         145 non-null    float64
#  7   Generosity             144 non-null    float64
#  8   Corruption             138 non-null    float64
#  9   Positive affect        145 non-null    float64
#  10  Negative affect        146 non-null    float64
#  11  Government confidence  122 non-null    float64
# dtypes: float64(10), object(2)
# memory usage: 14.8+ KB
#         Country  Year  Life Ladder    Log GDP  Social support  \
# 3   Afghanistan  2011     3.831719   7.552006        0.521104
# 16      Albania  2011     5.867422   9.310439        0.759434
# 28      Algeria  2011     5.317194   9.312737        0.810234
# 37       Angola  2011     5.589001   8.945782        0.723094
# 46    Argentina  2011     6.775805  10.112436        0.889073
#
#     Life Expectancy  Choice Freedom  Generosity  Corruption  Positive affect  \
# 3         51.400002        0.495901    0.167723    0.731109         0.479835
# 16        67.879997        0.487496   -0.204296    0.877003         0.565759
# 28        65.599998        0.529561   -0.182975    0.637982         0.502736
# 37        51.220001        0.583702    0.054426    0.911320         0.666833
# 46        66.419998        0.815802   -0.175919    0.754646         0.768943
#
#     Negative affect  Government confidence
# 3          0.267175               0.307386
# 16         0.256577                    NaN
# 28         0.254897                    NaN
# 37         0.361063               0.232387
# 46         0.231855               0.607538

# %% [markdown]
# ### View the country names for the year 2011
#
# - Think of which names may need correcting - like Hong Kong and Taiwan. Country names will be used later to connect with population data and the country names in both data frames will need to match.
# - Inspect to see if there are more than country info included.
# - Note  the `pd.options` line which allows you to see all the rows of country names. Once you run this code for a notebook, it is set as long as the notebook is active.

# %%
#https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html
#pd.options.display.max_rows = 999

# can only see some of the rows
print(yr2011['Country'])
# Out:
# 3       Afghanistan
# 16          Albania
# 28          Algeria
# 37           Angola
# 46        Argentina
#            ...
# 2019      Venezuela
# 2035        Vietnam
# 2049          Yemen
# 2062         Zambia
# 2078       Zimbabwe
# Name: Country, Length: 146, dtype: object

# %% [markdown]
# ### pd.options.display - note the output now
#
# When you look at the output in the previous cell, the first five countries are shown and the last five countries are shown; the countries in between are not visible. You can set the number of maximum rows to show with the `pd.options.display` command. In the cell below, the `max_rows` is set to 999 and all countries are displayed.  The setting is now in place for the remaining use of the notebook.

# %%
#https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html

# can now see all of the rows
pd.options.display.max_rows = 999
print(yr2011['Country'])
# Out:
# 3                     Afghanistan
# 16                        Albania
# 28                        Algeria
# 37                         Angola
# 46                      Argentina
# 62                        Armenia
# 76                      Australia
# 90                        Austria
# 106                    Azerbaijan
# 117                       Bahrain
# 131                    Bangladesh
# 146                       Belarus
# 159                       Belgium
# 173                         Benin
# 192                       Bolivia
# 206        Bosnia and Herzegovina
# 220                      Botswana
# 234                        Brazil
# 247                      Bulgaria
# 262                  Burkina Faso
# 275                       Burundi
# 283                      Cambodia
# 299                      Cameroon
# 315                        Canada
# 328      Central African Republic
# 336                          Chad
# 350                         Chile
# 366                         China
# 382                      Colombia
# 395                       Comoros
# 400           Congo (Brazzaville)
# 412              Congo (Kinshasa)
# 424                    Costa Rica
# 438                       Croatia
# 453                        Cyprus
# 467                       Czechia
# 482                       Denmark
# 496                      Djibouti
# 502            Dominican Republic
# 518                       Ecuador
# 534                         Egypt
# 550                   El Salvador
# 565                       Estonia
# 576                      Eswatini
# 591                       Finland
# 607                        France
# 618                         Gabon
# 637                       Georgia
# 653                       Germany
# 669                         Ghana
# 684                        Greece
# 700                     Guatemala
# 709                        Guinea
# 724                         Haiti
# 737                      Honduras
# 751     Hong Kong S.A.R. of China
# 763                       Hungary
# 788                         India
# 804                     Indonesia
# 818                          Iran
# 832                          Iraq
# 846                       Ireland
# 862                        Israel
# 878                         Italy
# 900                       Jamaica
# 912                         Japan
# 928                        Jordan
# 944                    Kazakhstan
# 960                         Kenya
# 975                        Kosovo
# 989                        Kuwait
# 1002                   Kyrgyzstan
# 1016                         Laos
# 1027                       Latvia
# 1043                      Lebanon
# 1054                      Lesotho
# 1078                    Lithuania
# 1091                   Luxembourg
# 1102                   Madagascar
# 1114                       Malawi
# 1129                     Malaysia
# 1142                         Mali
# 1155                        Malta
# 1170                   Mauritania
# 1179                    Mauritius
# 1192                       Mexico
# 1208                      Moldova
# 1222                     Mongolia
# 1236                   Montenegro
# 1247                      Morocco
# 1260                   Mozambique
# 1288                        Nepal
# 1303                  Netherlands
# 1318                  New Zealand
# 1334                    Nicaragua
# 1350                        Niger
# 1383              North Macedonia
# 1405                         Oman
# 1411                     Pakistan
# 1427      Palestinian Territories
# 1441                       Panama
# 1456                     Paraguay
# 1471                         Peru
# 1487                  Philippines
# 1502                       Poland
# 1516                     Portugal
# 1529                        Qatar
# 1536                      Romania
# 1552                       Russia
# 1566                       Rwanda
# 1580                 Saudi Arabia
# 1596                      Senegal
# 1610                       Serbia
# 1625                 Sierra Leone
# 1639                    Singapore
# 1650                     Slovakia
# 1664                     Slovenia
# 1680            Somaliland region
# 1687                 South Africa
# 1703                  South Korea
# 1723                        Spain
# 1739                    Sri Lanka
# 1751                        Sudan
# 1760                       Sweden
# 1785                        Syria
# 1792     Taiwan Province of China
# 1808                   Tajikistan
# 1824                     Tanzania
# 1840                     Thailand
# 1853                         Togo
# 1863          Trinidad and Tobago
# 1868                      Tunisia
# 1884                       Turkey
# 1896                 Turkmenistan
# 1910                       Uganda
# 1926                      Ukraine
# 1940         United Arab Emirates
# 1956               United Kingdom
# 1972                United States
# 1988                      Uruguay
# 2003                   Uzbekistan
# 2019                    Venezuela
# 2035                      Vietnam
# 2049                        Yemen
# 2062                       Zambia
# 2078                     Zimbabwe
# Name: Country, dtype: object

# %% [markdown]
# ### Investigate the years to determine which should be included in the analysis

# %%
years = ['2015', '2016', '2017', '2018', '2019', '2020', '2021']

many_years = df[df['Year'].isin(years)]
many_years.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 953 entries, 7 to 2088
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                953 non-null    object
#  1   Year                   953 non-null    object
#  2   Life Ladder            953 non-null    float64
#  3   Log GDP                936 non-null    float64
#  4   Social support         951 non-null    float64
#  5   Life Expectancy        925 non-null    float64
#  6   Choice Freedom         943 non-null    float64
#  7   Generosity             932 non-null    float64
#  8   Corruption             897 non-null    float64
#  9   Positive affect        947 non-null    float64
#  10  Negative affect        947 non-null    float64
#  11  Government confidence  861 non-null    float64
# dtypes: float64(10), object(2)
# memory usage: 96.8+ KB

# %% [markdown]
# ### Missing values
#
# - Any row in the dataframe that does not have 953 non-null rows of data has missing data.
# - It is important to consider how a row of data can be recovered if at all possible.
# - In some data, there may be columns that can help populate other columns.
#   - For example, a missing `Age` value can be calculated from a `Birth_date` column.
# - It turns out with the data we are using, there is no way to fill in the gaps from other columns.
# - The option for this data is to drop all of the null rows.

# %%
many_years = many_years.dropna(inplace = False)
many_years.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 820 entries, 7 to 2088
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                820 non-null    object
#  1   Year                   820 non-null    object
#  2   Life Ladder            820 non-null    float64
#  3   Log GDP                820 non-null    float64
#  4   Social support         820 non-null    float64
#  5   Life Expectancy        820 non-null    float64
#  6   Choice Freedom         820 non-null    float64
#  7   Generosity             820 non-null    float64
#  8   Corruption             820 non-null    float64
#  9   Positive affect        820 non-null    float64
#  10  Negative affect        820 non-null    float64
#  11  Government confidence  820 non-null    float64
# dtypes: float64(10), object(2)
# memory usage: 83.3+ KB

# %% [markdown]
# ### Happiness data by years
#
# From the `value_counts` counts in the cell below, there are between 122 and 128 countries with data for the years of 2015-2019.  But the number of countries drop in 2020 to 99 and in 2021 to 100.

# %%
# look at counts per year without nulls
many_years['Year'].value_counts().sort_index()
# Out:
# 2015    125
# 2016    123
# 2017    128
# 2018    123
# 2019    122
# 2020     99
# 2021    100
# Name: Year, dtype: int64

# %% [markdown]
# ### Pandas Crosstab
#
# __[Pandas Crosstab](https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html)__

# %%
# look at Country and year to see what is missing
# margins = True gives a row and column total
cross = pd.crosstab(many_years['Country'],many_years['Year'], margins = True)
cross
# Out:
# Year                      2015  2016  2017  2018  2019  2020  2021  All
# Country
# Afghanistan                  1     1     1     1     1     0     0    5
# Albania                      1     1     1     1     1     1     1    7
# Argentina                    1     1     1     1     1     1     1    7
# Armenia                      1     1     1     1     1     0     1    6
# Australia                    1     1     1     1     1     1     1    7
# Austria                      1     1     1     1     1     1     1    7
# Azerbaijan                   1     1     1     1     1     0     0    5
# Bangladesh                   1     1     1     1     1     1     0    6
# Belarus                      1     1     1     1     1     0     0    5
# Belgium                      1     1     1     1     1     1     0    6
# Benin                        1     1     1     1     1     1     1    7
# Bhutan                       1     0     0     0     0     0     0    1
# Bolivia                      1     1     1     1     1     1     1    7
# Bosnia and Herzegovina       1     1     1     1     1     1     1    7
# Botswana                     1     1     1     1     1     0     0    5
# Brazil                       1     1     1     1     1     1     1    7
# Bulgaria                     1     1     1     1     1     1     1    7
# Burkina Faso                 1     1     1     1     1     1     1    7
# Cambodia                     1     1     1     0     0     0     0    3
# Cameroon                     1     1     1     1     1     1     1    7
# Canada                       1     1     1     1     1     1     1    7
# Central African Republic     0     1     1     0     0     0     0    2
# Chad                         1     1     1     1     1     0     0    5
# Chile                        1     1     1     1     1     1     1    7
# Colombia                     1     1     1     1     1     1     1    7
# Comoros                      0     0     0     1     1     0     0    2
# Congo (Brazzaville)          1     1     1     1     1     1     1    7
# Congo (Kinshasa)             1     1     1     0     0     0     0    3
# Costa Rica                   1     1     1     1     1     1     1    7
# Croatia                      1     1     1     1     1     1     1    7
# Cyprus                       1     1     1     1     1     1     0    6
# Czechia                      1     1     1     1     0     1     1    6
# Denmark                      1     1     1     1     1     1     1    7
# Dominican Republic           1     1     1     1     1     1     1    7
# Ecuador                      1     1     1     1     1     1     1    7
# Egypt                        1     1     0     0     0     0     1    3
# El Salvador                  1     1     1     1     1     1     1    7
# Estonia                      1     1     1     1     1     1     1    7
# Eswatini                     0     0     0     1     1     0     0    2
# Ethiopia                     1     1     1     1     1     1     0    6
# Finland                      1     1     1     1     1     1     1    7
# France                       1     1     1     1     1     1     1    7
# Gabon                        1     1     1     1     1     1     1    7
# Gambia                       0     0     1     1     1     0     0    3
# Georgia                      1     1     1     1     1     1     1    7
# Germany                      1     1     1     1     1     1     1    7
# Ghana                        1     1     1     1     1     1     1    7
# Greece                       1     1     1     1     1     1     1    7
# Guatemala                    1     1     1     1     1     0     0    5
# Guinea                       1     1     1     1     1     1     0    6
# Haiti                        1     1     1     1     0     0     0    4
# Honduras                     1     1     1     1     1     0     1    6
# Hungary                      1     1     1     1     1     1     1    7
# Iceland                      1     1     1     0     0     1     1    5
# India                        1     1     1     1     1     1     1    7
# Indonesia                    1     1     1     1     1     1     1    7
# Iran                         1     1     0     1     1     1     1    6
# Iraq                         1     1     1     1     0     1     1    6
# Ireland                      1     1     1     1     1     1     1    7
# Israel                       1     1     1     1     1     1     1    7
# Italy                        1     1     1     1     1     1     1    7
# Ivory Coast                  1     1     1     1     1     1     1    7
# Jamaica                      0     0     1     0     1     1     1    4
# Japan                        1     1     1     1     1     1     1    7
# Jordan                       0     0     0     0     0     0     1    1
# Kazakhstan                   1     1     1     1     1     1     1    7
# Kenya                        1     1     1     1     1     1     1    7
# Kyrgyzstan                   1     1     1     1     1     1     1    7
# Laos                         0     0     1     0     0     0     0    1
# Latvia                       1     1     1     1     1     1     1    7
# Lebanon                      1     1     1     1     1     1     1    7
# Lesotho                      0     1     1     0     1     0     0    3
# Liberia                      1     1     1     1     1     0     0    5
# Lithuania                    1     1     1     1     1     1     1    7
# Luxembourg                   1     1     1     1     1     0     0    5
# Madagascar                   1     1     1     1     1     0     0    5
# Malawi                       1     1     1     1     1     0     1    6
# Malaysia                     1     0     0     1     1     1     0    4
# Mali                         1     1     1     1     1     1     1    7
# Malta                        1     1     1     1     1     1     0    6
# Mauritania                   1     1     1     1     1     0     0    5
# Mauritius                    0     1     1     1     1     1     1    6
# Mexico                       1     1     1     1     1     1     1    7
# Moldova                      1     1     1     1     1     1     1    7
# Mongolia                     1     1     1     1     1     1     1    7
# Montenegro                   1     1     1     1     1     1     0    6
# Mozambique                   1     0     1     1     1     0     1    5
# Myanmar                      1     1     1     1     1     1     1    7
# Namibia                      0     0     1     1     1     1     1    5
# Nepal                        1     1     1     1     1     1     1    7
# Netherlands                  1     1     1     1     1     1     1    7
# New Zealand                  1     1     1     1     1     1     1    7
# Nicaragua                    1     1     1     1     1     1     1    7
# Niger                        1     1     1     1     1     0     0    5
# Nigeria                      1     1     1     1     1     1     1    7
# North Macedonia              1     1     1     1     1     1     1    7
# Norway                       1     1     1     1     1     1     1    7
# Pakistan                     1     1     1     1     1     0     0    5
# Panama                       1     1     1     1     1     0     1    6
# Paraguay                     1     1     1     0     1     1     1    6
# Peru                         1     1     1     1     1     1     1    7
# Philippines                  1     1     1     1     1     1     1    7
# Poland                       1     1     1     1     1     1     1    7
# Portugal                     1     1     1     1     1     1     1    7
# Romania                      1     1     1     1     1     1     1    7
# Russia                       1     1     1     1     1     1     1    7
# Rwanda                       0     1     1     1     1     0     0    4
# Senegal                      1     1     1     1     1     1     1    7
# Serbia                       1     1     1     1     1     1     1    7
# Sierra Leone                 1     1     1     1     1     0     1    6
# Singapore                    1     1     1     1     1     0     0    5
# Slovakia                     1     1     1     1     1     1     1    7
# Slovenia                     1     1     1     1     1     1     1    7
# Somalia                      1     1     0     0     0     0     0    2
# South Africa                 1     1     1     1     1     1     1    7
# South Korea                  1     1     1     1     1     1     1    7
# Spain                        1     1     1     1     1     1     1    7
# Sri Lanka                    1     0     1     1     1     1     1    6
# Sweden                       1     1     1     1     1     1     1    7
# Switzerland                  1     1     1     1     1     1     1    7
# Tajikistan                   1     1     1     0     0     0     0    3
# Tanzania                     1     1     1     1     1     1     1    7
# Thailand                     1     1     1     1     1     1     1    7
# Togo                         1     1     1     1     1     0     1    6
# Trinidad and Tobago          0     0     1     0     0     0     0    1
# Tunisia                      1     1     1     1     1     1     1    7
# Turkey                       1     1     1     1     1     1     1    7
# Uganda                       1     1     1     1     1     1     1    7
# Ukraine                      1     1     1     1     1     1     1    7
# United Kingdom               1     1     1     1     1     1     1    7
# United States                1     1     1     1     1     1     1    7
# Uruguay                      1     1     1     1     1     1     1    7
# Uzbekistan                   1     0     1     1     1     1     1    6
# Venezuela                    1     1     1     1     1     0     0    5
# Yemen                        1     0     0     1     0     0     0    2
# Zambia                       1     1     1     1     1     1     1    7
# Zimbabwe                     1     1     1     1     1     1     1    7
# All                        125   123   128   123   122    99   100  820

# %% [markdown]
# ### Results of crosstab
#
# A visual inspection of the crosstab does reveal the countries with no data for 2020 and 2021.  There are enough major countries with missing data that it will be better off for our study to omit 2020 and 2021.  The cell below shows the isolation of countries with five or less years of data.

# %% [markdown]
# ### Best practice on dataframe names
#
# - As you progress in the EDA process, there will end up being many dataframes created.  A naming convention is a good plan to put into place. Your naming convention should be one that makes sense to you and to anyone that you will share your code with.
# - A common mistake made is to use nonmeaningful names like df1, df2, df3, etc. The weakness with this plan is that it is difficult to easily know which is the most current dataframe.
# - A possible convention is to use `df` following by a suffix which denotes where you are in the EDA process.
#   - df_raw or dfRaw could be used when you first read in the raw data.
#   - df_clean or dfClean could be used after cleaning the data
#   - df_final or dfFinal could be used after creating new variables and you are ready to write out your file.
#   - There can be a number of additional suffixes that you may end up using.
# - Another convention is to use dataframe names that relate to your topic; this is especially useful if you have a number of files.
#   - Example: nfl2019, nfl2020, nfl2021 would be good names if you have three years of data that you will later combine.
#   - You can use this example and combine it with the suffix idea: nfl2019Raw, nfl2019Clean, nfl2019Final.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 4 (4 pts.)</b>:
#
# Create a new dataframe called `happy_final` to include 2015, 2016, 2017, 2018 and 2019 data.
# - Show the shape of your new dataframe.
# - Drop all nulls from happy_final.
# - Show the shape of the dataframe after the drop. Make sure the number of records have decreased.
# </div>

# %%
#TODO: Create dataframe called 'happy_final'
yrs = ['2015', '2016', '2017', '2018', '2019']

happy_final = df[df['Year'].isin(yrs)]

# %%
#TODO: Show the shape of happy_final dataframe
happy_final.shape

#TODO: drop the nulls from happy_final
happy_final = happy_final.dropna(inplace = False)
happy_final.info()

#TODO: Show the shape of happy_final dataframe
happy_final.shape
# Out:
# (718, 12)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 621 entries, 7 to 2086
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                621 non-null    object
#  1   Year                   621 non-null    object
#  2   Life Ladder            621 non-null    float64
#  3   Log GDP                621 non-null    float64
#  4   Social support         621 non-null    float64
#  5   Life Expectancy        621 non-null    float64
#  6   Choice Freedom         621 non-null    float64
#  7   Generosity             621 non-null    float64
#  8   Corruption             621 non-null    float64
#  9   Positive affect        621 non-null    float64
#  10  Negative affect        621 non-null    float64
#  11  Government confidence  621 non-null    float64
# dtypes: float64(10), object(2)
# memory usage: 63.1+ KB
# (621, 12)

# %% [markdown]
# ### Dataframe names continued
#
# In the cell below there are two new dataframes created, `cross` and `subset`. These names were chosen in such a way that they can be used again and again without the worry that they will interfere with or be overwritten by a dataframe that might be needed later.

# %%
#  what is missing per country
cross = pd.crosstab(happy_final['Country'],happy_final['Year'], margins = True)
type(cross)
subset = cross[cross['All'] < 5]
type(subset)
subset.sort_values(by = 'All')
# Out:
# pandas.core.frame.DataFrame
# pandas.core.frame.DataFrame
# Year                      2015  2016  2017  2018  2019  All
# Country
# Bhutan                       1     0     0     0     0    1
# Trinidad and Tobago          0     0     1     0     0    1
# Laos                         0     0     1     0     0    1
# Somalia                      1     1     0     0     0    2
# Eswatini                     0     0     0     1     1    2
# Egypt                        1     1     0     0     0    2
# Jamaica                      0     0     1     0     1    2
# Yemen                        1     0     0     1     0    2
# Central African Republic     0     1     1     0     0    2
# Comoros                      0     0     0     1     1    2
# Cambodia                     1     1     1     0     0    3
# Tajikistan                   1     1     1     0     0    3
# Namibia                      0     0     1     1     1    3
# Malaysia                     1     0     0     1     1    3
# Lesotho                      0     1     1     0     1    3
# Congo (Kinshasa)             1     1     1     0     0    3
# Iceland                      1     1     1     0     0    3
# Gambia                       0     0     1     1     1    3
# Iraq                         1     1     1     1     0    4
# Czechia                      1     1     1     1     0    4
# Mozambique                   1     0     1     1     1    4
# Iran                         1     1     0     1     1    4
# Paraguay                     1     1     1     0     1    4
# Rwanda                       0     1     1     1     1    4
# Sri Lanka                    1     0     1     1     1    4
# Haiti                        1     1     1     1     0    4
# Uzbekistan                   1     0     1     1     1    4
# Mauritius                    0     1     1     1     1    4

# %% [markdown]
# ### Happiness data wrap up
#
# At this point the happiness data is ready to be merged with the population data.  Even though there are some years missing from some of the countries, the merge process will only select those countries and years with both happiness data and population data.

# %% [markdown]
# ## Part II - Population data

# %% [markdown]
# __[Worldbank Data](https://data.worldbank.org/indicator/SP.POP.TOTL)__

# %% [markdown]
#
# When you look at the data in the popuation file, you can see that the first row is not the header.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Big picture plan of merging two dataframes
#
# Our goal is to create one final dataframe that contains data for the happiness measures and population data. Here are some important details to know about merging dataframes.
# - You will need common fields in each dataframe to merge on and in our case it is two columns - `Country and Year`.
# - For every  `Country+Year` combination, we will have one row of data.
# - The merge of data will be an inner join between the two tables so that we end up with both happiness and population data.  If one dataframe has data for the `Country+Year` combination of a row but not the other file, then that data is dropped.
# - For example, if there is Population data for Egypt for 2019, but no happiness data, then the Egypt+2019 row of data is dropped completely from our final clean dataframe.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 5 (3 pts.)</b>:
#
# Read in csv file that contains the population data.
# - The file name is API_SP.POP.TOTL_DS2_en_csv_v2_4683828.csv. This is the actual name downloaded from the site.
# - Call your new dataframe `pop_raw`.
# - Make sure you have a proper header.
# - Display the first ten records and the info about the file.
# </div>

# %%
#TODO: Read in the file
import pandas as pd
pop_raw = pd.read_csv('rawpopcsv.csv', skiprows = (0,1,2,3))

pop_raw

#TODO: Display the dataframe info the info about the file
pop_raw.info
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                          Africa Eastern and Southern          AFE
# 2                                          Afghanistan          AFG
# 3                           Africa Western and Central          AFW
# 4                                               Angola          AGO
# 5                                              Albania          ALB
# 6                                              Andorra          AND
# 7                                           Arab World          ARB
# 8                                 United Arab Emirates          ARE
# 9                                            Argentina          ARG
# 10                                             Armenia          ARM
# 11                                      American Samoa          ASM
# 12                                 Antigua and Barbuda          ATG
# 13                                           Australia          AUS
# 14                                             Austria          AUT
# 15                                          Azerbaijan          AZE
# 16                                             Burundi          BDI
# 17                                             Belgium          BEL
# 18                                               Benin          BEN
# 19                                        Burkina Faso          BFA
# 20                                          Bangladesh          BGD
# 21                                            Bulgaria          BGR
# 22                                             Bahrain          BHR
# 23                                        Bahamas, The          BHS
# 24                              Bosnia and Herzegovina          BIH
# 25                                             Belarus          BLR
# 26                                              Belize          BLZ
# 27                                             Bermuda          BMU
# 28                                             Bolivia          BOL
# 29                                              Brazil          BRA
# 30                                            Barbados          BRB
# 31                                   Brunei Darussalam          BRN
# 32                                              Bhutan          BTN
# 33                                            Botswana          BWA
# 34                            Central African Republic          CAF
# 35                                              Canada          CAN
# 36                      Central Europe and the Baltics          CEB
# 37                                         Switzerland          CHE
# 38                                     Channel Islands          CHI
# 39                                               Chile          CHL
# 40                                               China          CHN
# 41                                       Cote d'Ivoire          CIV
# 42                                            Cameroon          CMR
# 43                                    Congo, Dem. Rep.          COD
# 44                                         Congo, Rep.          COG
# 45                                            Colombia          COL
# 46                                             Comoros          COM
# 47                                          Cabo Verde          CPV
# 48                                          Costa Rica          CRI
# 49                              Caribbean small states          CSS
# 50                                                Cuba          CUB
# 51                                             Curacao          CUW
# 52                                      Cayman Islands          CYM
# 53                                              Cyprus          CYP
# 54                                             Czechia          CZE
# 55                                             Germany          DEU
# 56                                            Djibouti          DJI
# 57                                            Dominica          DMA
# 58                                             Denmark          DNK
# 59                                  Dominican Republic          DOM
# 60                                             Algeria          DZA
# 61         East Asia & Pacific (excluding high income)          EAP
# 62                          Early-demographic dividend          EAR
# 63                                 East Asia & Pacific          EAS
# 64       Europe & Central Asia (excluding high income)          ECA
# 65                               Europe & Central Asia          ECS
# 66                                             Ecuador          ECU
# 67                                    Egypt, Arab Rep.          EGY
# 68                                           Euro area          EMU
# 69                                             Eritrea          ERI
# 70                                               Spain          ESP
# 71                                             Estonia          EST
# 72                                            Ethiopia          ETH
# 73                                      European Union          EUU
# 74            Fragile and conflict affected situations          FCS
# 75                                             Finland          FIN
# 76                                                Fiji          FJI
# 77                                              France          FRA
# 78                                       Faroe Islands          FRO
# 79                               Micronesia, Fed. Sts.          FSM
# 80                                               Gabon          GAB
# 81                                      United Kingdom          GBR
# 82                                             Georgia          GEO
# 83                                               Ghana          GHA
# 84                                           Gibraltar          GIB
# 85                                              Guinea          GIN
# 86                                         Gambia, The          GMB
# 87                                       Guinea-Bissau          GNB
# 88                                   Equatorial Guinea          GNQ
# 89                                              Greece          GRC
# 90                                             Grenada          GRD
# 91                                           Greenland          GRL
# 92                                           Guatemala          GTM
# 93                                                Guam          GUM
# 94                                              Guyana          GUY
# 95                                         High income          HIC
# 96                                Hong Kong SAR, China          HKG
# 97                                            Honduras          HND
# 98              Heavily indebted poor countries (HIPC)          HPC
# 99                                             Croatia          HRV
# 100                                              Haiti          HTI
# 101                                            Hungary          HUN
# 102                                          IBRD only          IBD
# 103                                   IDA & IBRD total          IBT
# 104                                          IDA total          IDA
# 105                                          IDA blend          IDB
# 106                                          Indonesia          IDN
# 107                                           IDA only          IDX
# 108                                        Isle of Man          IMN
# 109                                              India          IND
# 110                                     Not classified          INX
# 111                                            Ireland          IRL
# 112                                 Iran, Islamic Rep.          IRN
# 113                                               Iraq          IRQ
# 114                                            Iceland          ISL
# 115                                             Israel          ISR
# 116                                              Italy          ITA
# 117                                            Jamaica          JAM
# 118                                             Jordan          JOR
# 119                                              Japan          JPN
# 120                                         Kazakhstan          KAZ
# 121                                              Kenya          KEN
# 122                                    Kyrgyz Republic          KGZ
# 123                                           Cambodia          KHM
# 124                                           Kiribati          KIR
# 125                                St. Kitts and Nevis          KNA
# 126                                        Korea, Rep.          KOR
# 127                                             Kuwait          KWT
# 128  Latin America & Caribbean (excluding high income)          LAC
# 129                                            Lao PDR          LAO
# 130                                            Lebanon          LBN
# 131                                            Liberia          LBR
# 132                                              Libya          LBY
# 133                                          St. Lucia          LCA
# 134                          Latin America & Caribbean          LCN
# 135       Least developed countries: UN classification          LDC
# 136                                         Low income          LIC
# 137                                      Liechtenstein          LIE
# 138                                          Sri Lanka          LKA
# 139                                Lower middle income          LMC
# 140                                Low & middle income          LMY
# 141                                            Lesotho          LSO
# 142                          Late-demographic dividend          LTE
# 143                                          Lithuania          LTU
# 144                                         Luxembourg          LUX
# 145                                             Latvia          LVA
# 146                                   Macao SAR, China          MAC
# 147                           St. Martin (French part)          MAF
# 148                                            Morocco          MAR
# 149                                             Monaco          MCO
# 150                                            Moldova          MDA
# 151                                         Madagascar          MDG
# 152                                           Maldives          MDV
# 153                         Middle East & North Africa          MEA
# 154                                             Mexico          MEX
# 155                                   Marshall Islands          MHL
# 156                                      Middle income          MIC
# 157                                    North Macedonia          MKD
# 158                                               Mali          MLI
# 159                                              Malta          MLT
# 160                                            Myanmar          MMR
# 161  Middle East & North Africa (excluding high inc...          MNA
# 162                                         Montenegro          MNE
# 163                                           Mongolia          MNG
# 164                           Northern Mariana Islands          MNP
# 165                                         Mozambique          MOZ
# 166                                         Mauritania          MRT
# 167                                          Mauritius          MUS
# 168                                             Malawi          MWI
# 169                                           Malaysia          MYS
# 170                                      North America          NAC
# 171                                            Namibia          NAM
# 172                                      New Caledonia          NCL
# 173                                              Niger          NER
# 174                                            Nigeria          NGA
# 175                                          Nicaragua          NIC
# 176                                        Netherlands          NLD
# 177                                             Norway          NOR
# 178                                              Nepal          NPL
# 179                                              Nauru          NRU
# 180                                        New Zealand          NZL
# 181                                       OECD members          OED
# 182                                               Oman          OMN
# 183                                 Other small states          OSS
# 184                                           Pakistan          PAK
# 185                                             Panama          PAN
# 186                                               Peru          PER
# 187                                        Philippines          PHL
# 188                                              Palau          PLW
# 189                                   Papua New Guinea          PNG
# 190                                             Poland          POL
# 191                           Pre-demographic dividend          PRE
# 192                                        Puerto Rico          PRI
# 193                          Korea, Dem. People's Rep.          PRK
# 194                                           Portugal          PRT
# 195                                           Paraguay          PRY
# 196                                 West Bank and Gaza          PSE
# 197                        Pacific island small states          PSS
# 198                          Post-demographic dividend          PST
# 199                                   French Polynesia          PYF
# 200                                              Qatar          QAT
# 201                                            Romania          ROU
# 202                                 Russian Federation          RUS
# 203                                             Rwanda          RWA
# 204                                         South Asia          SAS
# 205                                       Saudi Arabia          SAU
# 206                                              Sudan          SDN
# 207                                            Senegal          SEN
# 208                                          Singapore          SGP
# 209                                    Solomon Islands          SLB
# 210                                       Sierra Leone          SLE
# 211                                        El Salvador          SLV
# 212                                         San Marino          SMR
# 213                                            Somalia          SOM
# 214                                             Serbia          SRB
# 215         Sub-Saharan Africa (excluding high income)          SSA
# 216                                        South Sudan          SSD
# 217                                 Sub-Saharan Africa          SSF
# 218                                       Small states          SST
# 219                              Sao Tome and Principe          STP
# 220                                           Suriname          SUR
# 221                                    Slovak Republic          SVK
# 222                                           Slovenia          SVN
# 223                                             Sweden          SWE
# 224                                           Eswatini          SWZ
# 225                          Sint Maarten (Dutch part)          SXM
# 226                                         Seychelles          SYC
# 227                               Syrian Arab Republic          SYR
# 228                           Turks and Caicos Islands          TCA
# 229                                               Chad          TCD
# 230         East Asia & Pacific (IDA & IBRD countries)          TEA
# 231       Europe & Central Asia (IDA & IBRD countries)          TEC
# 232                                               Togo          TGO
# 233                                           Thailand          THA
# 234                                         Tajikistan          TJK
# 235                                       Turkmenistan          TKM
# 236  Latin America & the Caribbean (IDA & IBRD coun...          TLA
# 237                                        Timor-Leste          TLS
# 238  Middle East & North Africa (IDA & IBRD countries)          TMN
# 239                                              Tonga          TON
# 240                            South Asia (IDA & IBRD)          TSA
# 241          Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 242                                Trinidad and Tobago          TTO
# 243                                            Tunisia          TUN
# 244                                            Turkiye          TUR
# 245                                             Tuvalu          TUV
# 246                                           Tanzania          TZA
# 247                                             Uganda          UGA
# 248                                            Ukraine          UKR
# 249                                Upper middle income          UMC
# 250                                            Uruguay          URY
# 251                                      United States          USA
# 252                                         Uzbekistan          UZB
# 253                     St. Vincent and the Grenadines          VCT
# 254                                      Venezuela, RB          VEN
# 255                             British Virgin Islands          VGB
# 256                              Virgin Islands (U.S.)          VIR
# 257                                            Vietnam          VNM
# 258                                            Vanuatu          VUT
# 259                                              World          WLD
# 260                                              Samoa          WSM
# 261                                             Kosovo          XKX
# 262                                        Yemen, Rep.          YEM
# 263                                       South Africa          ZAF
# 264                                             Zambia          ZMB
# 265                                           Zimbabwe          ZWE
#
#         Indicator Name Indicator Code          1960          1961  \
# 0    Population, total    SP.POP.TOTL  5.420800e+04  5.543400e+04
# 1    Population, total    SP.POP.TOTL  1.308368e+08  1.341598e+08
# 2    Population, total    SP.POP.TOTL  8.996967e+06  9.169406e+06
# 3    Population, total    SP.POP.TOTL  9.639642e+07  9.840722e+07
# 4    Population, total    SP.POP.TOTL  5.454938e+06  5.531451e+06
# 5    Population, total    SP.POP.TOTL  1.608800e+06  1.659800e+06
# 6    Population, total    SP.POP.TOTL  1.341000e+04  1.437800e+04
# 7    Population, total    SP.POP.TOTL  9.219772e+07  9.472454e+07
# 8    Population, total    SP.POP.TOTL  9.241700e+04  1.008010e+05
# 9    Population, total    SP.POP.TOTL  2.048178e+07  2.081727e+07
# 10   Population, total    SP.POP.TOTL  1.874119e+06  1.941498e+06
# 11   Population, total    SP.POP.TOTL  2.012700e+04  2.060500e+04
# 12   Population, total    SP.POP.TOTL  5.413200e+04  5.500500e+04
# 13   Population, total    SP.POP.TOTL  1.027648e+07  1.048300e+07
# 14   Population, total    SP.POP.TOTL  7.047539e+06  7.086299e+06
# 15   Population, total    SP.POP.TOTL  3.895398e+06  4.030325e+06
# 16   Population, total    SP.POP.TOTL  2.797925e+06  2.852438e+06
# 17   Population, total    SP.POP.TOTL  9.153489e+06  9.183948e+06
# 18   Population, total    SP.POP.TOTL  2.431617e+06  2.465865e+06
# 19   Population, total    SP.POP.TOTL  4.829289e+06  4.894580e+06
# 20   Population, total    SP.POP.TOTL  4.801350e+07  4.936283e+07
# 21   Population, total    SP.POP.TOTL  7.867374e+06  7.943118e+06
# 22   Population, total    SP.POP.TOTL  1.624290e+05  1.678990e+05
# 23   Population, total    SP.POP.TOTL  1.095320e+05  1.151190e+05
# 24   Population, total    SP.POP.TOTL  3.225664e+06  3.288604e+06
# 25   Population, total    SP.POP.TOTL  8.198000e+06  8.271216e+06
# 26   Population, total    SP.POP.TOTL  9.206800e+04  9.470000e+04
# 27   Population, total    SP.POP.TOTL  4.440000e+04  4.550000e+04
# 28   Population, total    SP.POP.TOTL  3.656961e+06  3.728954e+06
# 29   Population, total    SP.POP.TOTL  7.217924e+07  7.431134e+07
# 30   Population, total    SP.POP.TOTL  2.309850e+05  2.317180e+05
# 31   Population, total    SP.POP.TOTL  8.170700e+04  8.556000e+04
# 32   Population, total    SP.POP.TOTL  2.232840e+05  2.288490e+05
# 33   Population, total    SP.POP.TOTL  5.027330e+05  5.126880e+05
# 34   Population, total    SP.POP.TOTL  1.501668e+06  1.526057e+06
# 35   Population, total    SP.POP.TOTL  1.790901e+07  1.827100e+07
# 36   Population, total    SP.POP.TOTL  9.140176e+07  9.223274e+07
# 37   Population, total    SP.POP.TOTL  5.327827e+06  5.434294e+06
# 38   Population, total    SP.POP.TOTL  1.094190e+05  1.103980e+05
# 39   Population, total    SP.POP.TOTL  8.132988e+06  8.303804e+06
# 40   Population, total    SP.POP.TOTL  6.670700e+08  6.603300e+08
# 41   Population, total    SP.POP.TOTL  3.503559e+06  3.631547e+06
# 42   Population, total    SP.POP.TOTL  5.176920e+06  5.285015e+06
# 43   Population, total    SP.POP.TOTL  1.524826e+07  1.563770e+07
# 44   Population, total    SP.POP.TOTL  1.018254e+06  1.043119e+06
# 45   Population, total    SP.POP.TOTL  1.605771e+07  1.656782e+07
# 46   Population, total    SP.POP.TOTL  1.911220e+05  1.941490e+05
# 47   Population, total    SP.POP.TOTL  2.017700e+05  2.053210e+05
# 48   Population, total    SP.POP.TOTL  1.330787e+06  1.381187e+06
# 49   Population, total    SP.POP.TOTL  4.194711e+06  4.274052e+06
# 50   Population, total    SP.POP.TOTL  7.141241e+06  7.291201e+06
# 51   Population, total    SP.POP.TOTL  1.248260e+05  1.261250e+05
# 52   Population, total    SP.POP.TOTL  7.870000e+03  8.024000e+03
# 53   Population, total    SP.POP.TOTL  5.729330e+05  5.764020e+05
# 54   Population, total    SP.POP.TOTL  9.602006e+06  9.586651e+06
# 55   Population, total    SP.POP.TOTL  7.281490e+07  7.337763e+07
# 56   Population, total    SP.POP.TOTL  8.363400e+04  8.850300e+04
# 57   Population, total    SP.POP.TOTL  6.002000e+04  6.103600e+04
# 58   Population, total    SP.POP.TOTL  4.579603e+06  4.611687e+06
# 59   Population, total    SP.POP.TOTL  3.294222e+06  3.406282e+06
# 60   Population, total    SP.POP.TOTL  1.105786e+07  1.133634e+07
# 61   Population, total    SP.POP.TOTL  8.948855e+08  8.944895e+08
# 62   Population, total    SP.POP.TOTL  9.800033e+08  1.003195e+09
# 63   Population, total    SP.POP.TOTL  1.041674e+09  1.043657e+09
# 64   Population, total    SP.POP.TOTL  2.562403e+08  2.603763e+08
# 65   Population, total    SP.POP.TOTL  6.667534e+08  6.744507e+08
# 66   Population, total    SP.POP.TOTL  4.543658e+06  4.674176e+06
# 67   Population, total    SP.POP.TOTL  2.663289e+07  2.736624e+07
# 68   Population, total    SP.POP.TOTL  2.652040e+08  2.676211e+08
# 69   Population, total    SP.POP.TOTL  1.007586e+06  1.033320e+06
# 70   Population, total    SP.POP.TOTL  3.045500e+07  3.073925e+07
# 71   Population, total    SP.POP.TOTL  1.211537e+06  1.225077e+06
# 72   Population, total    SP.POP.TOTL  2.215128e+07  2.267119e+07
# 73   Population, total    SP.POP.TOTL  3.569061e+08  3.599984e+08
# 74   Population, total    SP.POP.TOTL  2.451340e+08  2.502744e+08
# 75   Population, total    SP.POP.TOTL  4.429634e+06  4.461005e+06
# 76   Population, total    SP.POP.TOTL  3.934800e+05  4.072440e+05
# 77   Population, total    SP.POP.TOTL  4.662169e+07  4.724053e+07
# 78   Population, total    SP.POP.TOTL  3.462400e+04  3.507400e+04
# 79   Population, total    SP.POP.TOTL  4.451000e+04  4.593900e+04
# 80   Population, total    SP.POP.TOTL  5.009220e+05  5.057930e+05
# 81   Population, total    SP.POP.TOTL  5.240000e+07  5.280000e+07
# 82   Population, total    SP.POP.TOTL  3.645600e+06  3.703600e+06
# 83   Population, total    SP.POP.TOTL  6.635229e+06  6.848291e+06
# 84   Population, total    SP.POP.TOTL  2.342000e+04  2.380800e+04
# 85   Population, total    SP.POP.TOTL  3.494164e+06  3.552068e+06
# 86   Population, total    SP.POP.TOTL  3.650490e+05  3.724360e+05
# 87   Population, total    SP.POP.TOTL  6.161400e+05  6.227540e+05
# 88   Population, total    SP.POP.TOTL  2.553380e+05  2.587860e+05
# 89   Population, total    SP.POP.TOTL  8.331725e+06  8.398050e+06
# 90   Population, total    SP.POP.TOTL  8.992700e+04  9.132400e+04
# 91   Population, total    SP.POP.TOTL  3.250000e+04  3.370000e+04
# 92   Population, total    SP.POP.TOTL  4.128880e+06  4.251911e+06
# 93   Population, total    SP.POP.TOTL  6.673300e+04  6.806500e+04
# 94   Population, total    SP.POP.TOTL  5.718130e+05  5.892740e+05
# 95   Population, total    SP.POP.TOTL  7.793138e+08  7.892117e+08
# 96   Population, total    SP.POP.TOTL  3.075605e+06  3.168100e+06
# 97   Population, total    SP.POP.TOTL  2.038636e+06  2.096407e+06
# 98   Population, total    SP.POP.TOTL  1.617343e+08  1.655731e+08
# 99   Population, total    SP.POP.TOTL  4.140181e+06  4.167292e+06
# 100  Population, total    SP.POP.TOTL  3.866162e+06  3.941956e+06
# 101  Population, total    SP.POP.TOTL  9.983967e+06  1.002932e+07
# 102  Population, total    SP.POP.TOTL  1.919643e+09  1.940357e+09
# 103  Population, total    SP.POP.TOTL  2.299245e+09  2.329155e+09
# 104  Population, total    SP.POP.TOTL  3.796021e+08  3.887977e+08
# 105  Population, total    SP.POP.TOTL  1.203916e+08  1.232710e+08
# 106  Population, total    SP.POP.TOTL  8.775107e+07  9.009840e+07
# 107  Population, total    SP.POP.TOTL  2.592104e+08  2.655267e+08
# 108  Population, total    SP.POP.TOTL  4.844400e+04  4.828600e+04
# 109  Population, total    SP.POP.TOTL  4.505477e+08  4.596422e+08
# 110  Population, total    SP.POP.TOTL           NaN           NaN
# 111  Population, total    SP.POP.TOTL  2.828600e+06  2.824400e+06
# 112  Population, total    SP.POP.TOTL  2.190691e+07  2.248037e+07
# 113  Population, total    SP.POP.TOTL  7.289753e+06  7.475349e+06
# 114  Population, total    SP.POP.TOTL  1.755740e+05  1.790290e+05
# 115  Population, total    SP.POP.TOTL  2.114020e+06  2.185000e+06
# 116  Population, total    SP.POP.TOTL  5.019970e+07  5.053635e+07
# 117  Population, total    SP.POP.TOTL  1.628524e+06  1.651067e+06
# 118  Population, total    SP.POP.TOTL  9.331020e+05  9.739830e+05
# 119  Population, total    SP.POP.TOTL  9.321600e+07  9.405500e+07
# 120  Population, total    SP.POP.TOTL  9.934564e+06  1.034942e+07
# 121  Population, total    SP.POP.TOTL  8.120082e+06  8.377693e+06
# 122  Population, total    SP.POP.TOTL  2.172300e+06  2.255900e+06
# 123  Population, total    SP.POP.TOTL  5.722372e+06  5.872968e+06
# 124  Population, total    SP.POP.TOTL  4.119600e+04  4.223400e+04
# 125  Population, total    SP.POP.TOTL  5.119900e+04  5.119600e+04
# 126  Population, total    SP.POP.TOTL  2.501237e+07  2.576567e+07
# 127  Population, total    SP.POP.TOTL  2.690260e+05  3.005810e+05
# 128  Population, total    SP.POP.TOTL  1.959905e+08  2.014683e+08
# 129  Population, total    SP.POP.TOTL  2.120892e+06  2.170340e+06
# 130  Population, total    SP.POP.TOTL  1.804935e+06  1.864613e+06
# 131  Population, total    SP.POP.TOTL  1.118655e+06  1.142304e+06
# 132  Population, total    SP.POP.TOTL  1.448416e+06  1.498076e+06
# 133  Population, total    SP.POP.TOTL  8.969800e+04  9.071800e+04
# 134  Population, total    SP.POP.TOTL  2.198288e+08  2.259127e+08
# 135  Population, total    SP.POP.TOTL  2.404547e+08  2.460479e+08
# 136  Population, total    SP.POP.TOTL  1.408531e+08  1.440128e+08
# 137  Population, total    SP.POP.TOTL  1.650100e+04  1.689400e+04
# 138  Population, total    SP.POP.TOTL  9.874476e+06  1.011164e+07
# 139  Population, total    SP.POP.TOTL  9.886261e+08  1.011301e+09
# 140  Population, total    SP.POP.TOTL  2.244700e+09  2.273945e+09
# 141  Population, total    SP.POP.TOTL  8.372640e+05  8.528920e+05
# 142  Population, total    SP.POP.TOTL  1.096903e+09  1.099285e+09
# 143  Population, total    SP.POP.TOTL  2.778550e+06  2.823550e+06
# 144  Population, total    SP.POP.TOTL  3.139700e+05  3.168450e+05
# 145  Population, total    SP.POP.TOTL  2.120979e+06  2.152681e+06
# 146  Population, total    SP.POP.TOTL  1.677950e+05  1.704660e+05
# 147  Population, total    SP.POP.TOTL  3.898000e+03  3.996000e+03
# 148  Population, total    SP.POP.TOTL  1.232853e+07  1.271059e+07
# 149  Population, total    SP.POP.TOTL  2.246100e+04  2.281300e+04
# 150  Population, total    SP.POP.TOTL  2.043664e+06  2.092667e+06
# 151  Population, total    SP.POP.TOTL  5.099368e+06  5.223561e+06
# 152  Population, total    SP.POP.TOTL  8.987300e+04  9.232800e+04
# 153  Population, total    SP.POP.TOTL  1.052032e+08  1.080618e+08
# 154  Population, total    SP.POP.TOTL  3.777186e+07  3.896605e+07
# 155  Population, total    SP.POP.TOTL  1.467400e+04  1.505600e+04
# 156  Population, total    SP.POP.TOTL  2.103847e+09  2.129932e+09
# 157  Population, total    SP.POP.TOTL  1.488670e+06  1.507647e+06
# 158  Population, total    SP.POP.TOTL  5.263727e+06  5.322269e+06
# 159  Population, total    SP.POP.TOTL  3.265500e+05  3.252500e+05
# 160  Population, total    SP.POP.TOTL  2.173695e+07  2.221163e+07
# 161  Population, total    SP.POP.TOTL  9.755314e+07  1.001471e+08
# 162  Population, total    SP.POP.TOTL  4.805790e+05  4.911400e+05
# 163  Population, total    SP.POP.TOTL  9.555140e+05  9.821810e+05
# 164  Population, total    SP.POP.TOTL  9.980000e+03  1.024300e+04
# 165  Population, total    SP.POP.TOTL  7.184870e+06  7.342117e+06
# 166  Population, total    SP.POP.TOTL  8.503770e+05  8.755860e+05
# 167  Population, total    SP.POP.TOTL  6.593510e+05  6.807570e+05
# 168  Population, total    SP.POP.TOTL  3.659980e+06  3.747758e+06
# 169  Population, total    SP.POP.TOTL  8.156342e+06  8.417821e+06
# 170  Population, total    SP.POP.TOTL  1.986244e+08  2.020075e+08
# 171  Population, total    SP.POP.TOTL  6.341380e+05  6.492740e+05
# 172  Population, total    SP.POP.TOTL  7.900000e+04  8.120000e+04
# 173  Population, total    SP.POP.TOTL  3.388774e+06  3.486322e+06
# 174  Population, total    SP.POP.TOTL  4.513846e+07  4.606357e+07
# 175  Population, total    SP.POP.TOTL  1.773132e+06  1.829772e+06
# 176  Population, total    SP.POP.TOTL  1.148663e+07  1.163871e+07
# 177  Population, total    SP.POP.TOTL  3.581239e+06  3.609800e+06
# 178  Population, total    SP.POP.TOTL  1.010506e+07  1.026726e+07
# 179  Population, total    SP.POP.TOTL  4.377000e+03  4.627000e+03
# 180  Population, total    SP.POP.TOTL  2.371800e+06  2.419700e+06
# 181  Population, total    SP.POP.TOTL  8.094132e+08  8.206904e+08
# 182  Population, total    SP.POP.TOTL  5.517350e+05  5.648910e+05
# 183  Population, total    SP.POP.TOTL  9.151857e+06  9.315834e+06
# 184  Population, total    SP.POP.TOTL  4.498869e+07  4.606523e+07
# 185  Population, total    SP.POP.TOTL  1.133005e+06  1.167120e+06
# 186  Population, total    SP.POP.TOTL  1.015501e+07  1.044662e+07
# 187  Population, total    SP.POP.TOTL  2.626974e+07  2.716105e+07
# 188  Population, total    SP.POP.TOTL  9.769000e+03  1.004600e+04
# 189  Population, total    SP.POP.TOTL  2.255858e+06  2.297052e+06
# 190  Population, total    SP.POP.TOTL  2.963745e+07  2.996400e+07
# 191  Population, total    SP.POP.TOTL  1.876171e+08  1.918897e+08
# 192  Population, total    SP.POP.TOTL  2.358000e+06  2.399722e+06
# 193  Population, total    SP.POP.TOTL  1.142419e+07  1.166559e+07
# 194  Population, total    SP.POP.TOTL  8.857716e+06  8.929316e+06
# 195  Population, total    SP.POP.TOTL  1.903990e+06  1.954552e+06
# 196  Population, total    SP.POP.TOTL           NaN           NaN
# 197  Population, total    SP.POP.TOTL  8.650640e+05  8.933940e+05
# 198  Population, total    SP.POP.TOTL  7.552298e+08  7.644235e+08
# 199  Population, total    SP.POP.TOTL  7.808000e+04  8.070500e+04
# 200  Population, total    SP.POP.TOTL  4.738300e+04  5.142700e+04
# 201  Population, total    SP.POP.TOTL  1.840690e+07  1.855525e+07
# 202  Population, total    SP.POP.TOTL  1.198970e+08  1.212360e+08
# 203  Population, total    SP.POP.TOTL  2.935575e+06  2.998334e+06
# 204  Population, total    SP.POP.TOTL  5.728395e+08  5.849397e+08
# 205  Population, total    SP.POP.TOTL  4.086534e+06  4.218852e+06
# 206  Population, total    SP.POP.TOTL  7.544498e+06  7.769475e+06
# 207  Population, total    SP.POP.TOTL  3.206757e+06  3.295280e+06
# 208  Population, total    SP.POP.TOTL  1.646400e+06  1.702400e+06
# 209  Population, total    SP.POP.TOTL  1.178470e+05  1.213850e+05
# 210  Population, total    SP.POP.TOTL  2.317638e+06  2.352370e+06
# 211  Population, total    SP.POP.TOTL  2.766319e+06  2.846601e+06
# 212  Population, total    SP.POP.TOTL  1.544000e+04  1.583600e+04
# 213  Population, total    SP.POP.TOTL  2.755967e+06  2.814125e+06
# 214  Population, total    SP.POP.TOTL  6.608000e+06  6.655000e+06
# 215  Population, total    SP.POP.TOTL  2.271915e+08  2.325241e+08
# 216  Population, total    SP.POP.TOTL  2.842718e+06  2.895609e+06
# 217  Population, total    SP.POP.TOTL  2.272332e+08  2.325670e+08
# 218  Population, total    SP.POP.TOTL  1.421163e+07  1.448328e+07
# 219  Population, total    SP.POP.TOTL  6.429400e+04  6.459700e+04
# 220  Population, total    SP.POP.TOTL  2.878700e+05  2.959130e+05
# 221  Population, total    SP.POP.TOTL  4.068095e+06  4.191667e+06
# 222  Population, total    SP.POP.TOTL  1.584720e+06  1.594131e+06
# 223  Population, total    SP.POP.TOTL  7.484656e+06  7.519998e+06
# 224  Population, total    SP.POP.TOTL  3.365780e+05  3.433460e+05
# 225  Population, total    SP.POP.TOTL  2.833000e+03  3.077000e+03
# 226  Population, total    SP.POP.TOTL  4.170000e+04  4.288900e+04
# 227  Population, total    SP.POP.TOTL  4.573514e+06  4.721893e+06
# 228  Population, total    SP.POP.TOTL  5.825000e+03  5.867000e+03
# 229  Population, total    SP.POP.TOTL  3.001604e+06  3.060365e+06
# 230  Population, total    SP.POP.TOTL  8.834456e+08  8.828080e+08
# 231  Population, total    SP.POP.TOTL  3.084249e+08  3.130629e+08
# 232  Population, total    SP.POP.TOTL  1.580508e+06  1.597523e+06
# 233  Population, total    SP.POP.TOTL  2.739721e+07  2.822419e+07
# 234  Population, total    SP.POP.TOTL  2.087053e+06  2.159134e+06
# 235  Population, total    SP.POP.TOTL  1.603254e+06  1.658364e+06
# 236  Population, total    SP.POP.TOTL  2.097490e+08  2.156300e+08
# 237  Population, total    SP.POP.TOTL  4.745350e+05  4.828520e+05
# 238  Population, total    SP.POP.TOTL  9.755314e+07  1.001471e+08
# 239  Population, total    SP.POP.TOTL  6.157400e+04  6.372100e+04
# 240  Population, total    SP.POP.TOTL  5.728395e+08  5.849397e+08
# 241  Population, total    SP.POP.TOTL  2.272332e+08  2.325670e+08
# 242  Population, total    SP.POP.TOTL  8.479730e+05  8.648140e+05
# 243  Population, total    SP.POP.TOTL  4.178235e+06  4.238141e+06
# 244  Population, total    SP.POP.TOTL  2.747234e+07  2.814691e+07
# 245  Population, total    SP.POP.TOTL  5.321000e+03  5.330000e+03
# 246  Population, total    SP.POP.TOTL  1.005215e+07  1.034670e+07
# 247  Population, total    SP.POP.TOTL  6.767092e+06  6.983824e+06
# 248  Population, total    SP.POP.TOTL  4.266465e+07  4.320635e+07
# 249  Population, total    SP.POP.TOTL  1.115221e+09  1.118631e+09
# 250  Population, total    SP.POP.TOTL  2.538648e+06  2.571682e+06
# 251  Population, total    SP.POP.TOTL  1.806710e+08  1.836910e+08
# 252  Population, total    SP.POP.TOTL  8.526299e+06  8.813619e+06
# 253  Population, total    SP.POP.TOTL  8.097000e+04  8.216800e+04
# 254  Population, total    SP.POP.TOTL  8.141839e+06  8.439261e+06
# 255  Population, total    SP.POP.TOTL  8.053000e+03  8.164000e+03
# 256  Population, total    SP.POP.TOTL  3.250000e+04  3.430000e+04
# 257  Population, total    SP.POP.TOTL  3.267005e+07  3.366611e+07
# 258  Population, total    SP.POP.TOTL  6.368900e+04  6.570000e+04
# 259  Population, total    SP.POP.TOTL  3.032156e+09  3.071596e+09
# 260  Population, total    SP.POP.TOTL  1.086270e+05  1.121120e+05
# 261  Population, total    SP.POP.TOTL  9.470000e+05  9.660000e+05
# 262  Population, total    SP.POP.TOTL  5.315351e+06  5.393034e+06
# 263  Population, total    SP.POP.TOTL  1.709984e+07  1.752453e+07
Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
# 5    1608800.0    1659800.0    1711319.0    1762621.0    1814135.0
# 6      13410.0      14378.0      15379.0      16407.0      17466.0
# 7   92197715.0   94724540.0   97334438.0  100034191.0  102832792.0
# 8      92417.0     100801.0     112112.0     125130.0     138049.0
# 9   20481781.0   20817270.0   21153042.0   21488916.0   21824427.0
#
#           1965  ...         2012         2013         2014         2015  \
# 0      57357.0  ...     102565.0     103165.0     103776.0     104339.0
# 1  148769974.0  ...  547482863.0  562601578.0  578075373.0  593871847.0
# 2    9956318.0  ...   31161378.0   32269592.0   33370804.0   34413603.0
# 3  107289875.0  ...  370243017.0  380437896.0  390882979.0  401586651.0
# 4    5770573.0  ...   25107925.0   26015786.0   26941773.0   27884380.0
# 5    1864791.0  ...    2900401.0    2895092.0    2889104.0    2880703.0
# 6      18542.0  ...      82427.0      80770.0      79213.0      77993.0
# 7  105736428.0  ...  371437642.0  379696477.0  387899835.0  396028301.0
# 8     149855.0  ...    9141598.0    9197908.0    9214182.0    9262896.0
# 9   22159644.0  ...   41733271.0   42202935.0   42669500.0   43131966.0
#
#           2016         2017         2018         2019         2020  \
# 0     104865.0     105361.0     105846.0     106310.0     106766.0
# 1  609978946.0  626392880.0  643090131.0  660046272.0  677243299.0
# 2   35383028.0   36296111.0   37171922.0   38041757.0   38928341.0
# 3  412551299.0  423769930.0  435229381.0  446911598.0  458803476.0
# 4   28842482.0   29816769.0   30809787.0   31825299.0   32866268.0
# 5    2876101.0    2873457.0    2866376.0    2854191.0    2837849.0
# 6      77295.0      76997.0      77008.0      77146.0      77265.0
# 7  404042892.0  411942825.0  419851989.0  427870273.0  436080728.0
# 8    9360975.0    9487206.0    9630966.0    9770526.0    9890400.0
# 9   43590368.0   44044811.0   44494502.0   44938712.0   45376763.0
#
#           2021
# 0     107195.0
# 1  694665117.0
# 2   39835428.0
# 3  470898870.0
# 4   33933611.0
# 5    2811666.0
# 6      77354.0
# 7  444517783.0
# 8    9991083.0
# 9   45808747.0
#
# [10 rows x 66 columns]

# %% [markdown]
# ### What if we don't want all of the columns?
#
# One option is to call out the columns you want to keep. In the case of the `Population` data, there are 67 columns and we will keep less than we will would need to delete. In our case, this is the better option

# %%
# creating a dataframe by listing what you want to keep
pop = pop_raw[['Country Name','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021']]
pop.info()
pop.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  266 non-null    object
#  1   2012          264 non-null    float64
#  2   2013          264 non-null    float64
#  3   2014          264 non-null    float64
#  4   2015          264 non-null    float64
#  5   2016          264 non-null    float64
#  6   2017          264 non-null    float64
#  7   2018          264 non-null    float64
#  8   2019          264 non-null    float64
#  9   2020          264 non-null    float64
#  10  2021          264 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 23.0+ KB
#                   Country Name         2012         2013         2014  \
# 0                        Aruba     102565.0     103165.0     103776.0
# 1  Africa Eastern and Southern  547482863.0  562601578.0  578075373.0
# 2                  Afghanistan   31161378.0   32269592.0   33370804.0
# 3   Africa Western and Central  370243017.0  380437896.0  390882979.0
# 4                       Angola   25107925.0   26015786.0   26941773.0
#
#           2015         2016         2017         2018         2019  \
# 0     104339.0     104865.0     105361.0     105846.0     106310.0
# 1  593871847.0  609978946.0  626392880.0  643090131.0  660046272.0
# 2   34413603.0   35383028.0   36296111.0   37171922.0   38041757.0
# 3  401586651.0  412551299.0  423769930.0  435229381.0  446911598.0
# 4   27884380.0   28842482.0   29816769.0   30809787.0   31825299.0
#
#           2020         2021
# 0     106766.0     107195.0
# 1  677243299.0  694665117.0
# 2   38928341.0   39835428.0
# 3  458803476.0  470898870.0
# 4   32866268.0   33933611.0

# %%
pop.tail()
# Out:
#      Country Name        2012        2013        2014        2015        2016  \
# 261        Kosovo   1807106.0   1818117.0   1812771.0   1788196.0   1777557.0
# 262   Yemen, Rep.  24473176.0  25147112.0  25823488.0  26497881.0  27168210.0
# 263  South Africa  52832659.0  53687125.0  54544184.0  55386369.0  56207649.0
# 264        Zambia  14465148.0  14926551.0  15399793.0  15879370.0  16363449.0
# 265      Zimbabwe  13115149.0  13350378.0  13586710.0  13814642.0  14030338.0
#
#            2017        2018        2019        2020        2021
# 261   1791003.0   1797085.0   1788878.0   1790133.0   1806279.0
# 262  27834811.0  28498683.0  29161922.0  29825968.0  30490639.0
# 263  57009751.0  57792520.0  58558267.0  59308690.0  60041996.0
# 264  16853608.0  17351714.0  17861034.0  18383956.0  18920657.0
# 265  14236599.0  14438812.0  14645473.0  14862927.0  15092171.0

# %% [markdown]
# ### Describe shows results in scientific notation

# %%
pop.describe()
# Out:
#                2012          2013          2014          2015          2016  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   2.874902e+08  2.912969e+08  2.951160e+08  2.989277e+08  3.027560e+08
# std    9.017511e+08  9.129343e+08  9.241050e+08  9.352101e+08  9.463321e+08
# min    1.013600e+04  1.020800e+04  1.028900e+04  1.037400e+04  1.047400e+04
# 25%    1.539939e+06  1.574621e+06  1.609909e+06  1.645868e+06  1.689616e+06
# 50%    9.824808e+06  9.948838e+06  1.001582e+07  1.022085e+07  1.036160e+07
# 75%    6.057984e+07  6.120753e+07  6.174243e+07  6.182699e+07  6.187352e+07
# max    7.089255e+09  7.175500e+09  7.261847e+09  7.347679e+09  7.433651e+09
#
#                2017          2018          2019          2020          2021
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   3.065980e+08  3.103591e+08  3.140425e+08  3.176734e+08  3.210893e+08
# std    9.575052e+08  9.683483e+08  9.788967e+08  9.891628e+08  9.988295e+08
# min    1.057700e+04  1.067800e+04  1.076400e+04  1.083400e+04  1.087300e+04
# 25%    1.716772e+06  1.740174e+06  1.751950e+06  1.767996e+06  1.791783e+06
# 50%    1.040671e+07  1.045548e+07  1.047907e+07  1.052565e+07  1.054019e+07
# 75%    6.191725e+07  6.193141e+07  6.150589e+07  6.157091e+07  6.295547e+07
# max    7.519371e+09  7.602716e+09  7.683806e+09  7.763933e+09  7.836631e+09

# %% [markdown]
# ### One way to fix is with `apply` and `lambda`

# %%
# use apply with lambda to format output
pop.describe().apply(lambda s: s.apply('{0:,.0f}'.format))
# Out:
#                 2012           2013           2014           2015  \
# count            264            264            264            264
# mean     287,490,206    291,296,912    295,115,985    298,927,729
# std      901,751,146    912,934,305    924,104,966    935,210,078
# min           10,136         10,208         10,289         10,374
# 25%        1,539,939      1,574,621      1,609,909      1,645,868
# 50%        9,824,808      9,948,838     10,015,825     10,220,854
# 75%       60,579,842     61,207,529     61,742,430     61,826,991
# max    7,089,254,548  7,175,500,378  7,261,846,543  7,347,679,005
#
#                 2016           2017           2018           2019  \
# count            264            264            264            264
# mean     302,756,007    306,597,966    310,359,117    314,042,483
# std      946,332,054    957,505,190    968,348,279    978,896,714
# min           10,474         10,577         10,678         10,764
# 25%        1,689,616      1,716,772      1,740,174      1,751,950
# 50%       10,361,595     10,406,706     10,455,484     10,479,066
# 75%       61,873,522     61,917,246     61,931,406     61,505,892
# max    7,433,650,819  7,519,371,102  7,602,716,232  7,683,806,444
#
#                 2020           2021
# count            264            264
# mean     317,673,389    321,089,334
# std      989,162,775    998,829,451
# min           10,834         10,873
# 25%        1,767,996      1,791,783
# 50%       10,525,650     10,540,190
# 75%       61,570,910     62,955,471
# max    7,763,932,702  7,836,630,792

# %% [markdown]
# ### What are the large population numbers?
#
# In looking at the large number in the describe function results, are these accurate or dirty data?
#
# - Some rows are legitimate countries and some are regions.
# - We don't want regions in our final data, but the good news is that since they are not in the happiness data, they will get dropped during the merge process!

# 170  3.639672e+08  3.659951e+08  3.696022e+08  3.702037e+08
# 174  1.958747e+08  2.009636e+08  2.061396e+08  2.114007e+08
# 181  1.358280e+09  1.365275e+09  1.372980e+09  1.375820e+09
# 184  2.122283e+08  2.165653e+08  2.208923e+08  2.251999e+08
# 191  9.194851e+08  9.449027e+08  9.707957e+08  9.971582e+08
# 198  1.110012e+09  1.113143e+09  1.117278e+09  1.116655e+09
# 204  1.814455e+09  1.835777e+09  1.856882e+09  1.877902e+09
# 215  1.078223e+09  1.106860e+09  1.135948e+09  1.165465e+09
# 217  1.078320e+09  1.106958e+09  1.136047e+09  1.165564e+09
# 230  2.066104e+09  2.078012e+09  2.088186e+09  2.096155e+09
# 231  4.589427e+08  4.607885e+08  4.621003e+08  4.626241e+08
# 236  6.246981e+08  6.306448e+08  6.364928e+08  6.422398e+08
# 238  3.783861e+08  3.847718e+08  3.913446e+08  3.981289e+08
# 240  1.814455e+09  1.835777e+09  1.856882e+09  1.877902e+09
# 241  1.078320e+09  1.106958e+09  1.136047e+09  1.165564e+09
# 249  2.466337e+09  2.480708e+09  2.492597e+09  2.501428e+09
# 251  3.268382e+08  3.283300e+08  3.315011e+08  3.318937e+08
# 259  7.602716e+09  7.683806e+09  7.763933e+09  7.836631e+09

# %% [markdown]
# ### Missing data
#
# The population data has 266 rows of data, yet all of the years only have 264 rows with non null values.  Let's take a look at the nulls.

# %%
# only including five fields for the test inspection
missing = pop[pop['2012'].isnull()][['Country Name','2012','2013','2018','2019']]
missing
# Out:
#        Country Name  2012  2013  2018  2019
# 69          Eritrea   NaN   NaN   NaN   NaN
# 110  Not classified   NaN   NaN   NaN   NaN

# %%
# drop the nulls
pop.shape
pop = pop.dropna()
pop.shape
pop.info()
# Out:
# (266, 11)
# (264, 11)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264 entries, 0 to 265
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  264 non-null    object
#  1   2012          264 non-null    float64
#  2   2013          264 non-null    float64
#  3   2014          264 non-null    float64
#  4   2015          264 non-null    float64
#  5   2016          264 non-null    float64
#  6   2017          264 non-null    float64
#  7   2018          264 non-null    float64
#  8   2019          264 non-null    float64
#  9   2020          264 non-null    float64
#  10  2021          264 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 24.8+ KB

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 6 (3 pts.)</b>:
#
# Change all float64 columns in the `pop` dataframe to type 'int64' and display the dataframe info.
# </div>

# %%
#TODO: Change all year columns to type 'int64'
pop = pop.astype({'2012':'int64', '2013':'int64', '2014':'int64', '2015':'int64', '2016':'int64', '2017':'int64', 
                 '2018':'int64', '2019':'int64', '2020':'int64', '2021':'int64'})

#TODO: Display the dataframe info
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264 entries, 0 to 265
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  264 non-null    object
#  1   2012          264 non-null    int64
#  2   2013          264 non-null    int64
#  3   2014          264 non-null    int64
#  4   2015          264 non-null    int64
#  5   2016          264 non-null    int64
#  6   2017          264 non-null    int64
#  7   2018          264 non-null    int64
#  8   2019          264 non-null    int64
#  9   2020          264 non-null    int64
#  10  2021          264 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 24.8+ KB

# %% [markdown]
# ### Creating a long file from a wide file - use Pandas melt
# - `id_vars` are the columns you will keep
# - `value_vars` are the columns you will take from wide to long (not used in this example)
# - `var_name` is the name of the column that represents what the wide columns represented
# - `value_name` is what you will call you value column
#
# __[Pandas melt](https://pandas.pydata.org/docs/reference/api/pandas.melt.html)__

# %%
# turn from wide file with years as a column header to a long file with year as a row
col = ['2012','2013','2014','2015','2016','2017','2018','2019','2020','2021']
pop_long = (pd.melt(pop, id_vars = ['Country Name'], value_vars = col, var_name = 'Year', value_name = 'Population'))
pop_long.info()
pop_long.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2640 entries, 0 to 2639
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  2640 non-null   object
#  1   Year          2640 non-null   object
#  2   Population    2640 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 62.0+ KB
#                   Country Name  Year  Population
# 0                        Aruba  2012      102565
# 1  Africa Eastern and Southern  2012   547482863
# 2                  Afghanistan  2012    31161378
# 3   Africa Western and Central  2012   370243017
# 4                       Angola  2012    25107925

# %% [markdown]
# ### The difference between wide and long file
#
# Depending on the analysis performed on the data, in some cases a `wide` format is needed and in others a `long` format is needed.
# - In the wide example shown here, the year value is the column header and the population are the values in the column.
#   - Values do not repeat in the first column.
# - In the long example, `Year` and `Population` are headers with the respective values within the columns.
#   - Values do repeat in the first column.
#   - Many plotting libraries require data in the long format.
#
# <div>
# <img src="attachment:image-2.png" width ="600", align = "left">
# </div>
# <br>

# %%
# with a wide file, you need to analyze each column separately
pop['2012'].mean()
pop['2013'].mean()
# Out:
# 287490206.0568182
# 291296911.9621212

# %%
# what is the mean population per year. A long file allows for a groupby.
pop_long.groupby('Year')['Population'].mean().map('{0:,.0f}'.format)
# Out:
# Year
# 2012    287,490,206
# 2013    291,296,912
# 2014    295,115,985
# 2015    298,927,729
# 2016    302,756,007
# 2017    306,597,966
# 2018    310,359,117
# 2019    314,042,483
# 2020    317,673,389
# 2021    321,089,334
# Name: Population, dtype: object

# %%
# could make the student do this?
pop_long = pop_long.rename(columns = {'Country Name':'Country'})
pop_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2640 entries, 0 to 2639
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     2640 non-null   object
#  1   Year        2640 non-null   object
#  2   Population  2640 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 62.0+ KB

# %% [markdown]
# ### Merging two files together
#
# __[Merging Files](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)__
#
# Look at the shape of `happy_final` that has 3 columns and look at `pop_long` which has 12 columns and the final goal will be to get the `Population` column linked up to the correct `Country + Year` combination.

# %%
pop_long.shape
happy_final.shape
pop_long.head()
happy_final.head()
# Out:
# (2640, 3)
# (621, 12)
#                        Country  Year  Population
# 0                        Aruba  2012      102565
# 1  Africa Eastern and Southern  2012   547482863
# 2                  Afghanistan  2012    31161378
# 3   Africa Western and Central  2012   370243017
# 4                       Angola  2012    25107925
#         Country  Year  Life Ladder   Log GDP  Social support  Life Expectancy  \
# 7   Afghanistan  2015     3.982855  7.634466        0.528597        52.599998
# 8   Afghanistan  2016     4.220169  7.629037        0.559072        52.924999
# 9   Afghanistan  2017     2.661718  7.629684        0.490880        53.250000
# 10  Afghanistan  2018     2.694303  7.617663        0.507516        53.575001
# 11  Afghanistan  2019     2.375092  7.632903        0.419973        53.900002
#
#     Choice Freedom  Generosity  Corruption  Positive affect  Negative affect  \
# 7         0.388928    0.085082    0.880638         0.491410         0.339276
# 8         0.522566    0.047488    0.793246         0.501409         0.348332
# 9         0.427011   -0.116068    0.954393         0.435270         0.371326
# 10        0.373536   -0.088125    0.927606         0.384561         0.404904
# 11        0.393656   -0.103467    0.923849         0.324108         0.502474
#
#     Government confidence
# 7                0.260557
# 8                0.324990
# 9                0.261179
# 10               0.364666
# 11               0.341482

# %% [markdown]
# ### After the merge
#
# We now have a dataframe with 13 columns. We went from 621 rows of happiness data to 566 rows of merged data.

# %%
merged = pd.merge(happy_final, pop_long, how = 'inner', on = ['Country','Year'])
merged.shape
merged.info()
# Out:
# (566, 13)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 566 entries, 0 to 565
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                566 non-null    object
#  1   Year                   566 non-null    object
#  2   Life Ladder            566 non-null    float64
#  3   Log GDP                566 non-null    float64
#  4   Social support         566 non-null    float64
#  5   Life Expectancy        566 non-null    float64
#  6   Choice Freedom         566 non-null    float64
#  7   Generosity             566 non-null    float64
#  8   Corruption             566 non-null    float64
#  9   Positive affect        566 non-null    float64
#  10  Negative affect        566 non-null    float64
#  11  Government confidence  566 non-null    float64
#  12  Population             566 non-null    int64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 61.9+ KB

# %%
# look at the population by year
merged.groupby('Year')['Population'].sum().map('{0:,.0f}'.format)
# Out:
# Year
# 2015    4,864,598,225
# 2016    4,834,090,250
# 2017    4,968,737,903
# 2018    5,019,358,357
# 2019    5,029,941,434
# Name: Population, dtype: object

# %%
# countries per year
merged['Year'].value_counts().sort_index()
# Out:
# 2015    113
# 2016    112
# 2017    117
# 2018    112
# 2019    112
# Name: Year, dtype: int64

# %% [markdown]
# ### Are all countries complete with five years of data
#
# Not all countries have five years of data.

# %%
# Check countries by years
cross = pd.crosstab(merged['Country'],merged['Year'], margins = True)
cross
# Out:
# Year                      2015  2016  2017  2018  2019  All
# Country
# Afghanistan                  1     1     1     1     1    5
# Albania                      1     1     1     1     1    5
# Argentina                    1     1     1     1     1    5
# Armenia                      1     1     1     1     1    5
# Australia                    1     1     1     1     1    5
# Austria                      1     1     1     1     1    5
# Azerbaijan                   1     1     1     1     1    5
# Bangladesh                   1     1     1     1     1    5
# Belarus                      1     1     1     1     1    5
# Belgium                      1     1     1     1     1    5
# Benin                        1     1     1     1     1    5
# Bhutan                       1     0     0     0     0    1
# Bolivia                      1     1     1     1     1    5
# Bosnia and Herzegovina       1     1     1     1     1    5
# Botswana                     1     1     1     1     1    5
# Brazil                       1     1     1     1     1    5
# Bulgaria                     1     1     1     1     1    5
# Burkina Faso                 1     1     1     1     1    5
# Cambodia                     1     1     1     0     0    3
# Cameroon                     1     1     1     1     1    5
# Canada                       1     1     1     1     1    5
# Central African Republic     0     1     1     0     0    2
# Chad                         1     1     1     1     1    5
# Chile                        1     1     1     1     1    5
# Colombia                     1     1     1     1     1    5
# Comoros                      0     0     0     1     1    2
# Costa Rica                   1     1     1     1     1    5
# Croatia                      1     1     1     1     1    5
# Cyprus                       1     1     1     1     1    5
# Czechia                      1     1     1     1     0    4
# Denmark                      1     1     1     1     1    5
# Dominican Republic           1     1     1     1     1    5
# Ecuador                      1     1     1     1     1    5
# El Salvador                  1     1     1     1     1    5
# Estonia                      1     1     1     1     1    5
# Eswatini                     0     0     0     1     1    2
# Ethiopia                     1     1     1     1     1    5
# Finland                      1     1     1     1     1    5
# France                       1     1     1     1     1    5
# Gabon                        1     1     1     1     1    5
# Georgia                      1     1     1     1     1    5
# Germany                      1     1     1     1     1    5
# Ghana                        1     1     1     1     1    5
# Greece                       1     1     1     1     1    5
# Guatemala                    1     1     1     1     1    5
# Guinea                       1     1     1     1     1    5
# Haiti                        1     1     1     1     0    4
# Honduras                     1     1     1     1     1    5
# Hungary                      1     1     1     1     1    5
# Iceland                      1     1     1     0     0    3
# India                        1     1     1     1     1    5
# Indonesia                    1     1     1     1     1    5
# Iraq                         1     1     1     1     0    4
# Ireland                      1     1     1     1     1    5
# Israel                       1     1     1     1     1    5
# Italy                        1     1     1     1     1    5
# Jamaica                      0     0     1     0     1    2
# Japan                        1     1     1     1     1    5
# Kazakhstan                   1     1     1     1     1    5
# Kenya                        1     1     1     1     1    5
# Latvia                       1     1     1     1     1    5
# Lebanon                      1     1     1     1     1    5
# Lesotho                      0     1     1     0     1    3
# Liberia                      1     1     1     1     1    5
# Lithuania                    1     1     1     1     1    5
# Luxembourg                   1     1     1     1     1    5
# Madagascar                   1     1     1     1     1    5
# Malawi                       1     1     1     1     1    5
# Malaysia                     1     0     0     1     1    3
# Mali                         1     1     1     1     1    5
# Malta                        1     1     1     1     1    5
# Mauritania                   1     1     1     1     1    5
# Mauritius                    0     1     1     1     1    4
# Mexico                       1     1     1     1     1    5
# Moldova                      1     1     1     1     1    5
# Mongolia                     1     1     1     1     1    5
# Montenegro                   1     1     1     1     1    5
# Mozambique                   1     0     1     1     1    4
# Myanmar                      1     1     1     1     1    5
# Namibia                      0     0     1     1     1    3
# Nepal                        1     1     1     1     1    5
# Netherlands                  1     1     1     1     1    5
# New Zealand                  1     1     1     1     1    5
# Nicaragua                    1     1     1     1     1    5
# Niger                        1     1     1     1     1    5
# Nigeria                      1     1     1     1     1    5
# North Macedonia              1     1     1     1     1    5
# Norway                       1     1     1     1     1    5
# Pakistan                     1     1     1     1     1    5
# Panama                       1     1     1     1     1    5
# Paraguay                     1     1     1     0     1    4
# Peru                         1     1     1     1     1    5
# Philippines                  1     1     1     1     1    5
# Poland                       1     1     1     1     1    5
# Portugal                     1     1     1     1     1    5
# Romania                      1     1     1     1     1    5
# Rwanda                       0     1     1     1     1    4
# Senegal                      1     1     1     1     1    5
# Serbia                       1     1     1     1     1    5
# Sierra Leone                 1     1     1     1     1    5
# Singapore                    1     1     1     1     1    5
# Slovenia                     1     1     1     1     1    5
# Somalia                      1     1     0     0     0    2
# South Africa                 1     1     1     1     1    5
# Spain                        1     1     1     1     1    5
# Sri Lanka                    1     0     1     1     1    4
# Sweden                       1     1     1     1     1    5
# Switzerland                  1     1     1     1     1    5
# Tajikistan                   1     1     1     0     0    3
# Tanzania                     1     1     1     1     1    5
# Thailand                     1     1     1     1     1    5
# Togo                         1     1     1     1     1    5
# Trinidad and Tobago          0     0     1     0     0    1
# Tunisia                      1     1     1     1     1    5
# Uganda                       1     1     1     1     1    5
# Ukraine                      1     1     1     1     1    5
# United Kingdom               1     1     1     1     1    5
# United States                1     1     1     1     1    5
# Uruguay                      1     1     1     1     1    5
# Uzbekistan                   1     0     1     1     1    4
# Zambia                       1     1     1     1     1    5
# Zimbabwe                     1     1     1     1     1    5
# All                        113   112   117   112   112  566

# %%
# how many countries have all five years of data
temp = cross[cross['All'] == 5]
len(temp)
temp.sort_values(by = 'All')
# Out:
# 100
# Year                    2015  2016  2017  2018  2019  All
# Country
# Afghanistan                1     1     1     1     1    5
# Norway                     1     1     1     1     1    5
# North Macedonia            1     1     1     1     1    5
# Nigeria                    1     1     1     1     1    5
# Niger                      1     1     1     1     1    5
# Nicaragua                  1     1     1     1     1    5
# New Zealand                1     1     1     1     1    5
# Netherlands                1     1     1     1     1    5
# Nepal                      1     1     1     1     1    5
# Myanmar                    1     1     1     1     1    5
# Montenegro                 1     1     1     1     1    5
# Mongolia                   1     1     1     1     1    5
# Moldova                    1     1     1     1     1    5
# Mexico                     1     1     1     1     1    5
# Mauritania                 1     1     1     1     1    5
# Malta                      1     1     1     1     1    5
# Mali                       1     1     1     1     1    5
# Malawi                     1     1     1     1     1    5
# Madagascar                 1     1     1     1     1    5
# Luxembourg                 1     1     1     1     1    5
# Lithuania                  1     1     1     1     1    5
# Liberia                    1     1     1     1     1    5
# Pakistan                   1     1     1     1     1    5
# Lebanon                    1     1     1     1     1    5
# Panama                     1     1     1     1     1    5
# Philippines                1     1     1     1     1    5
# Uruguay                    1     1     1     1     1    5
# United States              1     1     1     1     1    5
# United Kingdom             1     1     1     1     1    5
# Ukraine                    1     1     1     1     1    5
# Uganda                     1     1     1     1     1    5
# Tunisia                    1     1     1     1     1    5
# Togo                       1     1     1     1     1    5
# Thailand                   1     1     1     1     1    5
# Tanzania                   1     1     1     1     1    5
# Switzerland                1     1     1     1     1    5
# Sweden                     1     1     1     1     1    5
# Spain                      1     1     1     1     1    5
# South Africa               1     1     1     1     1    5
# Slovenia                   1     1     1     1     1    5
# Singapore                  1     1     1     1     1    5
# Sierra Leone               1     1     1     1     1    5
# Serbia                     1     1     1     1     1    5
# Senegal                    1     1     1     1     1    5
# Romania                    1     1     1     1     1    5
# Portugal                   1     1     1     1     1    5
# Poland                     1     1     1     1     1    5
# Peru                       1     1     1     1     1    5
# Latvia                     1     1     1     1     1    5
# Kenya                      1     1     1     1     1    5
# Kazakhstan                 1     1     1     1     1    5
# Colombia                   1     1     1     1     1    5
# Chile                      1     1     1     1     1    5
# Chad                       1     1     1     1     1    5
# Canada                     1     1     1     1     1    5
# Cameroon                   1     1     1     1     1    5
# Burkina Faso               1     1     1     1     1    5
# Bulgaria                   1     1     1     1     1    5
# Brazil                     1     1     1     1     1    5
# Botswana                   1     1     1     1     1    5
# Bosnia and Herzegovina     1     1     1     1     1    5
# Bolivia                    1     1     1     1     1    5
# Benin                      1     1     1     1     1    5
# Belgium                    1     1     1     1     1    5
# Belarus                    1     1     1     1     1    5
# Bangladesh                 1     1     1     1     1    5
# Azerbaijan                 1     1     1     1     1    5
# Austria                    1     1     1     1     1    5
# Australia                  1     1     1     1     1    5
# Armenia                    1     1     1     1     1    5
# Argentina                  1     1     1     1     1    5
# Albania                    1     1     1     1     1    5
# Costa Rica                 1     1     1     1     1    5
# Croatia                    1     1     1     1     1    5
# Cyprus                     1     1     1     1     1    5
# Denmark                    1     1     1     1     1    5
# Japan                      1     1     1     1     1    5
# Italy                      1     1     1     1     1    5
# Israel                     1     1     1     1     1    5
# Ireland                    1     1     1     1     1    5
# Indonesia                  1     1     1     1     1    5
# India                      1     1     1     1     1    5
# Hungary                    1     1     1     1     1    5
# Honduras                   1     1     1     1     1    5
# Guinea                     1     1     1     1     1    5
# Guatemala                  1     1     1     1     1    5
# Zambia                     1     1     1     1     1    5
# Greece                     1     1     1     1     1    5
# Germany                    1     1     1     1     1    5
# Georgia                    1     1     1     1     1    5
# Gabon                      1     1     1     1     1    5
# France                     1     1     1     1     1    5
# Finland                    1     1     1     1     1    5
# Ethiopia                   1     1     1     1     1    5
# Estonia                    1     1     1     1     1    5
# El Salvador                1     1     1     1     1    5
# Ecuador                    1     1     1     1     1    5
# Dominican Republic         1     1     1     1     1    5
# Ghana                      1     1     1     1     1    5
# Zimbabwe                   1     1     1     1     1    5

# %% [markdown]
# ### Write out the final file for use in the Module 6 Python Assignment

# %%
merged.to_csv('Happiness_clean.csv', header = True, index = False)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 7 (6 pts.)</b>:
#
# Using only 2019 data from the `merged` dataframe, answer the following questions:
# - Display the rows corresponding to the five countries with the `highest population`?
# - Display the rows corresponding to the five countries with the `highest Log GDP`?
# - Explain the results.  How do the two results differ and what can you conclude?
# </div>

# %%
#TODO: Create a dataframe for 2019
year2019 = merged[merged['Year'] == '2019'] 

#TODO: Display the dataframe info
year2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112 entries, 4 to 565
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                112 non-null    object
#  1   Year                   112 non-null    object
#  2   Life Ladder            112 non-null    float64
#  3   Log GDP                112 non-null    float64
#  4   Social support         112 non-null    float64
#  5   Life Expectancy        112 non-null    float64
#  6   Choice Freedom         112 non-null    float64
#  7   Generosity             112 non-null    float64
#  8   Corruption             112 non-null    float64
#  9   Positive affect        112 non-null    float64
#  10  Negative affect        112 non-null    float64
#  11  Government confidence  112 non-null    float64
#  12  Population             112 non-null    int64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 12.2+ KB

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 7 continued:</b> Display the rows corresponding to the five countries with the `highest population`?</div>

# %%
#TODO: Determine which five countries have the highest population
year2019.nlargest(5, 'Population')['Country']
# Out:
# 235            India
# 546    United States
# 240        Indonesia
# 413         Pakistan
# 75            Brazil
# Name: Country, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 7 continued:</b> Display the rows corresponding to the five countries with the `highest Log GDP`?.</div>

# %%
#TODO: Determine which five countries have the highest Log GDP
year2019.nlargest(5, 'Log GDP')['Country']
# Out:
# 304     Luxembourg
# 471      Singapore
# 249        Ireland
# 502    Switzerland
# 408         Norway
# Name: Country, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 8 (2 pts.)</b>:
#
# - Using a Markdown cell, explain the results.  How do the countries with the highest population differ from those with high Log GDP?
# </div>

# %% [markdown]
# According to my results, the five countries with the highest populations are India, the United States, Indonesia, Pakistan, and Brazil. These do not coincide with the five countries with the highest Log GDP which were found to be Luxemborg, Singapore, Ireland, Switzerland, and Norway. The countries with the highest populations differ from the countries with the highest Log GDP in that many of the countries with highest Log GDP are amongst the "happiest" countries.
